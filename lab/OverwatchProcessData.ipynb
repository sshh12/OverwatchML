# %%
# Imports

import numpy as np
import os

# %%
def get_competitive_rank(player, region):
    
    try:

        return int(player.json[region]['stats']['competitive']['overall_stats']['comprank'])

    except (TypeError, KeyError):

        return False

# %%
def get_vector_gamestats(player, region, gametype="competitive", stat_keys=None):
    
    if not stat_keys:
            
        stat_keys = general_stats
        
    try:

        stats = player.json[region]['stats'][gametype]['game_stats']
            
        vector = []
            
        for key in stat_keys:
                
            if 'overwatchguid' not in key:
                    
                if key not in stats:
                        
                    vector.append(0)
                        
                else:
                
                    vector.append(stats[key])
                
        return np.array(vector)

    except (TypeError, KeyError):

        return False

# %%
def get_vector_herostats(player, region, gametype='competitive', stat_keys=None):
    
    if not stat_keys:
        
        stat_keys = hero_stats
        
    try:

        stats = player.json[region]['heroes']['stats'][gametype]
            
        vector = []
            
        for stat in stat_keys:
            
            hero, stat_type, value = stat.split(" ")

            try:
                
                stat_num = stats[hero][stat_type][value]
                
                if isinstance(stat_num, str):
                    stat_num = float(stat_num.replace('%', ''))

                vector.append(stat_num)

            except (TypeError, KeyError):

                vector.append(0)
                
        return np.array(vector)

    except (TypeError, KeyError):

        return False

# %%
def get_vector_combined(player, region, gametype='competitive', stat_keys_general=None, stat_keys_heros=None):
    
    if not stat_keys_general:
        
        stat_keys_general = general_stats
        
    if not stat_keys_heros:
        
        stat_keys_heros = hero_stats
        
    vector_1 = get_vector_gamestats(player, region, gametype, stat_keys=stat_keys_general)
    vector_2 = get_vector_herostats(player, region, gametype, stat_keys=stat_keys_heros)
    
    try:
        
        return np.concatenate([vector_1, vector_2])
    
    except:
    
        return False

# %%
def print_hero_stat_list():
    
    import json
    
    hero_stats = []
    
    for filename in os.listdir(os.path.join('..', 'profiles')):
        
        with open(os.path.join('..', 'profiles', filename), 'r') as profile:

            player_json = profile.read()
        
        if 'error' not in player_json:
            
            try:
                
                player_json = json.loads(player_json)
            
                stats = player_json['us']['heroes']['stats']['competitive']

                for hero in stats:

                    for stat_type in stats[hero]:

                        for stat in stats[hero][stat_type]:
                            
                            stat_string = '{} {} {}'.format(hero, stat_type, stat)
                            
                            if stat_string not in hero_stats:

                                hero_stats.append(stat_string)
                            
            except:
                pass
        
    hero_stats.sort()
                        
    for stat in hero_stats:
        
        print("'" + stat + "',")

# print_hero_stat_list()

# %%
# Player Data Structure

gametype = ['competitive', 'quickplay']

general_stats = [
     'final_blows_avg_per_10_min',
     'offensive_assists_most_in_game',
     'melee_final_blows_most_in_game',
     'environmental_kills',
     'solo_kills_avg_per_10_min',
     'medals_gold',
     'healing_done_most_in_game',
     'final_blows',
     'solo_kills',
     'teleporter_pad_destroyed_most_in_game',
     'of_teams_hero_damage',
     'medals_bronze',
     'time_spent_on_fire_most_in_game',
     'hero_damage_done_most_in_game',
     'turrets_destroyed',
     'deaths',
     'defensive_assists',
     'games_tied',
     'kill_streak_best',
     'eliminations_avg_per_10_min',
     'time_played',
     'shield_generator_destroyed_most_in_game',
     'medals',
     'melee_percentage_of_final_blows',
     'all_damage_done',
     'all_damage_done_avg_per_10_min',
     'melee_final_blows_avg_per_10_min',
     'shield_generator_destroyed',
     'objective_kills_most_in_game',
     'barrier_damage_done_avg_per_10_min',
     'of_teams_damage',
     'objective_time',
     'games_lost',
     'time_spent_on_fire_avg_per_10_min',
     'healing_done_avg_per_10_min',
     'multikills',
     'kpd',
     'hero_damage_done',
     'objective_time_most_in_game',
     'objective_time_avg_per_10_min',
     'defensive_assists_most_in_game',
     'final_blows_most_in_game',
     'games_won',
     'deaths_avg_per_10_min',
     'damage_blocked',
     'solo_kills_most_in_game',
     'recon_assists',
     'melee_final_blows',
     'recon_assists_most_in_game',
     'cards',
     'all_damage_done_most_in_game',
     'multikill_best',
     'environmental_kills_most_in_game',
     'turrets_destroyed_most_in_game',
     'objective_kills',
     'medals_silver',
     'games_played',
     'weapon_accuracy',
     'eliminations',
     'offensive_assists',
     'hero_damage_done_avg_per_10_min',
     'eliminations_most_in_game',
     'barrier_damage_done',
     'time_spent_on_fire',
     'environmental_deaths',
     'teleporter_pads_destroyed',
     'healing_done',
     'objective_kills_avg_per_10_min'
]

hero_stats = [
    'ana average_stats average_energy',
    'ana general_stats all_damage_done',
    'ana general_stats all_damage_done_most_in_game',
    'ana general_stats all_damage_done_most_in_life',
    'ana general_stats barrier_damage_done',
    'ana general_stats barrier_damage_done_most_in_game',
    'ana general_stats card',
    'ana general_stats cards',
    'ana general_stats death',
    'ana general_stats deaths',
    'ana general_stats defensive_assist',
    'ana general_stats defensive_assist_most_in_game',
    'ana general_stats defensive_assists',
    'ana general_stats defensive_assists_most_in_game',
    'ana general_stats elimination',
    'ana general_stats elimination_most_in_game',
    'ana general_stats elimination_most_in_life',
    'ana general_stats elimination_per_life',
    'ana general_stats eliminations',
    'ana general_stats eliminations_most_in_game',
    'ana general_stats eliminations_most_in_life',
    'ana general_stats eliminations_per_life',
    'ana general_stats environmental_kill',
    'ana general_stats environmental_kills',
    'ana general_stats final_blow',
    'ana general_stats final_blow_most_in_game',
    'ana general_stats final_blows',
    'ana general_stats final_blows_most_in_game',
    'ana general_stats games_lost',
    'ana general_stats games_played',
    'ana general_stats games_tied',
    'ana general_stats games_won',
    'ana general_stats healing_done',
    'ana general_stats healing_done_most_in_game',
    'ana general_stats hero_damage_done',
    'ana general_stats hero_damage_done_most_in_game',
    'ana general_stats hero_damage_done_most_in_life',
    'ana general_stats kill_streak_best',
    'ana general_stats medals',
    'ana general_stats medals_bronze',
    'ana general_stats medals_gold',
    'ana general_stats medals_silver',
    'ana general_stats melee_final_blow',
    'ana general_stats melee_final_blow_most_in_game',
    'ana general_stats melee_final_blows',
    'ana general_stats melee_final_blows_most_in_game',
    'ana general_stats multikill',
    'ana general_stats multikill_best',
    'ana general_stats multikills',
    'ana general_stats objective_kill',
    'ana general_stats objective_kill_most_in_game',
    'ana general_stats objective_kills',
    'ana general_stats objective_kills_most_in_game',
    'ana general_stats objective_time',
    'ana general_stats objective_time_most_in_game',
    'ana general_stats offensive_assist',
    'ana general_stats offensive_assist_most_in_game',
    'ana general_stats offensive_assists',
    'ana general_stats offensive_assists_most_in_game',
    'ana general_stats quick_melee_accuracy',
    'ana general_stats shield_generator_destroyed',
    'ana general_stats shield_generators_destroyed',
    'ana general_stats solo_kill',
    'ana general_stats solo_kill_most_in_game',
    'ana general_stats solo_kills',
    'ana general_stats solo_kills_most_in_game',
    'ana general_stats teleporter_pad_destroyed',
    'ana general_stats teleporter_pads_destroyed',
    'ana general_stats time_played',
    'ana general_stats time_spent_on_fire',
    'ana general_stats time_spent_on_fire_most_in_game',
    'ana general_stats turret_destroyed',
    'ana general_stats turrets_destroyed',
    'ana general_stats weapon_accuracy',
    'ana general_stats weapon_accuracy_best_in_game',
    'ana general_stats win_percentage',
    'ana hero_stats biotic_grenade_kill',
    'ana hero_stats biotic_grenade_kills',
    'ana hero_stats enemies_slept',
    'ana hero_stats enemies_slept_most_in_game',
    'ana hero_stats enemy_slept',
    'ana hero_stats enemy_slept_most_in_game',
    'ana hero_stats mech_deaths',
    'ana hero_stats nano_boost_applied',
    'ana hero_stats nano_boost_applied_most_in_game',
    'ana hero_stats nano_boost_assist',
    'ana hero_stats nano_boost_assist_most_in_game',
    'ana hero_stats nano_boost_assists',
    'ana hero_stats nano_boost_assists_most_in_game',
    'ana hero_stats nano_boosts_applied',
    'ana hero_stats nano_boosts_applied_most_in_game',
    'ana hero_stats scoped_accuracy',
    'ana hero_stats scoped_accuracy_best_in_game',
    'ana hero_stats self_healing',
    'ana hero_stats self_healing_most_in_game',
    'ana hero_stats unscoped_accuracy',
    'ana hero_stats unscoped_accuracy_best_in_game',
    'ana rolling_average_stats all_damage_done',
    'ana rolling_average_stats barrier_damage_done',
    'ana rolling_average_stats deaths',
    'ana rolling_average_stats defensive_assists',
    'ana rolling_average_stats eliminations',
    'ana rolling_average_stats enemies_slept',
    'ana rolling_average_stats final_blows',
    'ana rolling_average_stats healing_done',
    'ana rolling_average_stats hero_damage_done',
    'ana rolling_average_stats melee_final_blows',
    'ana rolling_average_stats nano_boost_assists',
    'ana rolling_average_stats nano_boosts_applied',
    'ana rolling_average_stats objective_kills',
    'ana rolling_average_stats objective_time',
    'ana rolling_average_stats offensive_assists',
    'ana rolling_average_stats self_healing',
    'ana rolling_average_stats solo_kills',
    'ana rolling_average_stats time_spent_on_fire',
    'bastion average_stats average_energy',
    'bastion general_stats all_damage_done',
    'bastion general_stats all_damage_done_most_in_game',
    'bastion general_stats all_damage_done_most_in_life',
    'bastion general_stats barrier_damage_done',
    'bastion general_stats barrier_damage_done_most_in_game',
    'bastion general_stats card',
    'bastion general_stats cards',
    'bastion general_stats critical_hit',
    'bastion general_stats critical_hit_accuracy',
    'bastion general_stats critical_hit_most_in_game',
    'bastion general_stats critical_hit_most_in_life',
    'bastion general_stats critical_hits',
    'bastion general_stats critical_hits_most_in_game',
    'bastion general_stats critical_hits_most_in_life',
    'bastion general_stats death',
    'bastion general_stats deaths',
    'bastion general_stats elimination',
    'bastion general_stats elimination_most_in_game',
    'bastion general_stats elimination_most_in_life',
    'bastion general_stats elimination_per_life',
    'bastion general_stats eliminations',
    'bastion general_stats eliminations_most_in_game',
    'bastion general_stats eliminations_most_in_life',
    'bastion general_stats eliminations_per_life',
    'bastion general_stats environmental_kill',
    'bastion general_stats environmental_kills',
    'bastion general_stats final_blow',
    'bastion general_stats final_blow_most_in_game',
    'bastion general_stats final_blows',
    'bastion general_stats final_blows_most_in_game',
    'bastion general_stats games_lost',
    'bastion general_stats games_played',
    'bastion general_stats games_tied',
    'bastion general_stats games_won',
    'bastion general_stats healing_done',
    'bastion general_stats hero_damage_done',
    'bastion general_stats hero_damage_done_most_in_game',
    'bastion general_stats hero_damage_done_most_in_life',
    'bastion general_stats kill_streak_best',
    'bastion general_stats medals',
    'bastion general_stats medals_bronze',
    'bastion general_stats medals_gold',
    'bastion general_stats medals_silver',
    'bastion general_stats melee_final_blow',
    'bastion general_stats melee_final_blow_most_in_game',
    'bastion general_stats melee_final_blows',
    'bastion general_stats melee_final_blows_most_in_game',
    'bastion general_stats multikill',
    'bastion general_stats multikill_best',
    'bastion general_stats multikills',
    'bastion general_stats objective_kill',
    'bastion general_stats objective_kill_most_in_game',
    'bastion general_stats objective_kills',
    'bastion general_stats objective_kills_most_in_game',
    'bastion general_stats objective_time',
    'bastion general_stats objective_time_most_in_game',
    'bastion general_stats overwatchguid0x0860000000000033',
    'bastion general_stats quick_melee_accuracy',
    'bastion general_stats shield_generator_destroyed',
    'bastion general_stats shield_generators_destroyed',
    'bastion general_stats solo_kill',
    'bastion general_stats solo_kill_most_in_game',
    'bastion general_stats solo_kills',
    'bastion general_stats solo_kills_most_in_game',
    'bastion general_stats teleporter_pad_destroyed',
    'bastion general_stats teleporter_pads_destroyed',
    'bastion general_stats time_played',
    'bastion general_stats time_spent_on_fire',
    'bastion general_stats time_spent_on_fire_most_in_game',
    'bastion general_stats turret_destroyed',
    'bastion general_stats turrets_destroyed',
    'bastion general_stats weapon_accuracy',
    'bastion general_stats weapon_accuracy_best_in_game',
    'bastion general_stats win_percentage',
    'bastion hero_stats biotic_field_healing_done',
    'bastion hero_stats recon_kill',
    'bastion hero_stats recon_kill_most_in_game',
    'bastion hero_stats recon_kills',
    'bastion hero_stats recon_kills_most_in_game',
    'bastion hero_stats self_healing',
    'bastion hero_stats self_healing_most_in_game',
    'bastion hero_stats sentry_kill',
    'bastion hero_stats sentry_kill_most_in_game',
    'bastion hero_stats sentry_kills',
    'bastion hero_stats sentry_kills_most_in_game',
    'bastion hero_stats tank_kill',
    'bastion hero_stats tank_kill_most_in_game',
    'bastion hero_stats tank_kills',
    'bastion hero_stats tank_kills_most_in_game',
    'bastion rolling_average_stats all_damage_done',
    'bastion rolling_average_stats barrier_damage_done',
    'bastion rolling_average_stats critical_hits',
    'bastion rolling_average_stats deaths',
    'bastion rolling_average_stats eliminations',
    'bastion rolling_average_stats final_blows',
    'bastion rolling_average_stats healing_done',
    'bastion rolling_average_stats hero_damage_done',
    'bastion rolling_average_stats melee_final_blows',
    'bastion rolling_average_stats objective_kills',
    'bastion rolling_average_stats objective_time',
    'bastion rolling_average_stats recon_kills',
    'bastion rolling_average_stats self_healing',
    'bastion rolling_average_stats sentry_kills',
    'bastion rolling_average_stats solo_kills',
    'bastion rolling_average_stats tank_kills',
    'bastion rolling_average_stats time_spent_on_fire',
    'doomfist general_stats all_damage_done',
    'doomfist general_stats all_damage_done_most_in_game',
    'doomfist general_stats all_damage_done_most_in_life',
    'doomfist general_stats barrier_damage_done',
    'doomfist general_stats barrier_damage_done_most_in_game',
    'doomfist general_stats card',
    'doomfist general_stats cards',
    'doomfist general_stats death',
    'doomfist general_stats deaths',
    'doomfist general_stats elimination',
    'doomfist general_stats elimination_most_in_game',
    'doomfist general_stats elimination_most_in_life',
    'doomfist general_stats elimination_per_life',
    'doomfist general_stats eliminations',
    'doomfist general_stats eliminations_most_in_game',
    'doomfist general_stats eliminations_most_in_life',
    'doomfist general_stats eliminations_per_life',
    'doomfist general_stats environmental_kill',
    'doomfist general_stats environmental_kills',
    'doomfist general_stats final_blow',
    'doomfist general_stats final_blow_most_in_game',
    'doomfist general_stats final_blows',
    'doomfist general_stats final_blows_most_in_game',
    'doomfist general_stats games_lost',
    'doomfist general_stats games_played',
    'doomfist general_stats games_tied',
    'doomfist general_stats games_won',
    'doomfist general_stats hero_damage_done',
    'doomfist general_stats hero_damage_done_most_in_game',
    'doomfist general_stats hero_damage_done_most_in_life',
    'doomfist general_stats kill_streak_best',
    'doomfist general_stats medals',
    'doomfist general_stats medals_bronze',
    'doomfist general_stats medals_gold',
    'doomfist general_stats medals_silver',
    'doomfist general_stats melee_final_blow',
    'doomfist general_stats melee_final_blow_most_in_game',
    'doomfist general_stats melee_final_blows',
    'doomfist general_stats melee_final_blows_most_in_game',
    'doomfist general_stats multikill',
    'doomfist general_stats multikill_best',
    'doomfist general_stats multikills',
    'doomfist general_stats objective_kill',
    'doomfist general_stats objective_kill_most_in_game',
    'doomfist general_stats objective_kills',
    'doomfist general_stats objective_kills_most_in_game',
    'doomfist general_stats objective_time',
    'doomfist general_stats objective_time_most_in_game',
    'doomfist general_stats quick_melee_accuracy',
    'doomfist general_stats shield_generator_destroyed',
    'doomfist general_stats shield_generators_destroyed',
    'doomfist general_stats solo_kill',
    'doomfist general_stats solo_kill_most_in_game',
    'doomfist general_stats solo_kills',
    'doomfist general_stats solo_kills_most_in_game',
    'doomfist general_stats teleporter_pad_destroyed',
    'doomfist general_stats teleporter_pads_destroyed',
    'doomfist general_stats time_played',
    'doomfist general_stats time_spent_on_fire',
    'doomfist general_stats time_spent_on_fire_most_in_game',
    'doomfist general_stats turret_destroyed',
    'doomfist general_stats turrets_destroyed',
    'doomfist general_stats weapon_accuracy',
    'doomfist general_stats weapon_accuracy_best_in_game',
    'doomfist general_stats win_percentage',
    'doomfist hero_stats ability_damage_done',
    'doomfist hero_stats ability_damage_done_most_in_game',
    'doomfist hero_stats meteor_strike_kill',
    'doomfist hero_stats meteor_strike_kill_most_in_game',
    'doomfist hero_stats meteor_strike_kills',
    'doomfist hero_stats meteor_strike_kills_most_in_game',
    'doomfist hero_stats shields_created',
    'doomfist hero_stats shields_created_most_in_game',
    'doomfist rolling_average_stats ability_damage_done',
    'doomfist rolling_average_stats all_damage_done',
    'doomfist rolling_average_stats barrier_damage_done',
    'doomfist rolling_average_stats deaths',
    'doomfist rolling_average_stats eliminations',
    'doomfist rolling_average_stats final_blows',
    'doomfist rolling_average_stats hero_damage_done',
    'doomfist rolling_average_stats melee_final_blows',
    'doomfist rolling_average_stats meteor_strike_kills',
    'doomfist rolling_average_stats objective_kills',
    'doomfist rolling_average_stats objective_time',
    'doomfist rolling_average_stats shields_created',
    'doomfist rolling_average_stats solo_kills',
    'doomfist rolling_average_stats time_spent_on_fire',
    'dva average_stats average_energy',
    'dva average_stats teleporter_uptime_average',
    'dva general_stats all_damage_done',
    'dva general_stats all_damage_done_most_in_game',
    'dva general_stats all_damage_done_most_in_life',
    'dva general_stats barrier_damage_done',
    'dva general_stats barrier_damage_done_most_in_game',
    'dva general_stats card',
    'dva general_stats cards',
    'dva general_stats critical_hit',
    'dva general_stats critical_hit_accuracy',
    'dva general_stats critical_hit_most_in_game',
    'dva general_stats critical_hit_most_in_life',
    'dva general_stats critical_hits',
    'dva general_stats critical_hits_most_in_game',
    'dva general_stats critical_hits_most_in_life',
    'dva general_stats death',
    'dva general_stats deaths',
    'dva general_stats elimination',
    'dva general_stats elimination_most_in_game',
    'dva general_stats elimination_most_in_life',
    'dva general_stats elimination_per_life',
    'dva general_stats eliminations',
    'dva general_stats eliminations_most_in_game',
    'dva general_stats eliminations_most_in_life',
    'dva general_stats eliminations_per_life',
    'dva general_stats environmental_kill',
    'dva general_stats environmental_kills',
    'dva general_stats final_blow',
    'dva general_stats final_blow_most_in_game',
    'dva general_stats final_blows',
    'dva general_stats final_blows_most_in_game',
    'dva general_stats game_lost',
    'dva general_stats games_lost',
    'dva general_stats games_played',
    'dva general_stats games_tied',
    'dva general_stats games_won',
    'dva general_stats healing_done',
    'dva general_stats hero_damage_done',
    'dva general_stats hero_damage_done_most_in_game',
    'dva general_stats hero_damage_done_most_in_life',
    'dva general_stats kill_streak_best',
    'dva general_stats medals',
    'dva general_stats medals_bronze',
    'dva general_stats medals_gold',
    'dva general_stats medals_silver',
    'dva general_stats melee_final_blow',
    'dva general_stats melee_final_blow_most_in_game',
    'dva general_stats melee_final_blows',
    'dva general_stats melee_final_blows_most_in_game',
    'dva general_stats multikill',
    'dva general_stats multikill_best',
    'dva general_stats multikills',
    'dva general_stats objective_kill',
    'dva general_stats objective_kill_most_in_game',
    'dva general_stats objective_kills',
    'dva general_stats objective_kills_most_in_game',
    'dva general_stats objective_time',
    'dva general_stats objective_time_most_in_game',
    'dva general_stats overwatchguid0x0860000000000033',
    'dva general_stats quick_melee_accuracy',
    'dva general_stats shield_generator_destroyed',
    'dva general_stats shield_generators_destroyed',
    'dva general_stats solo_kill',
    'dva general_stats solo_kill_most_in_game',
    'dva general_stats solo_kills',
    'dva general_stats solo_kills_most_in_game',
    'dva general_stats teleporter_pad_destroyed',
    'dva general_stats teleporter_pads_destroyed',
    'dva general_stats time_played',
    'dva general_stats time_spent_on_fire',
    'dva general_stats time_spent_on_fire_most_in_game',
    'dva general_stats turret_destroyed',
    'dva general_stats turrets_destroyed',
    'dva general_stats weapon_accuracy',
    'dva general_stats weapon_accuracy_best_in_game',
    'dva general_stats win_percentage',
    'dva hero_stats damage_blocked',
    'dva hero_stats damage_blocked_most_in_game',
    'dva hero_stats mech_called',
    'dva hero_stats mech_called_most_in_game',
    'dva hero_stats mech_death',
    'dva hero_stats mech_deaths',
    'dva hero_stats mechs_called',
    'dva hero_stats mechs_called_most_in_game',
    'dva hero_stats self_destruct_kill',
    'dva hero_stats self_destruct_kill_most_in_game',
    'dva hero_stats self_destruct_kills',
    'dva hero_stats self_destruct_kills_most_in_game',
    'dva hero_stats self_healing',
    'dva hero_stats teleporter_uptime',
    'dva hero_stats turret_kills',
    'dva rolling_average_stats all_damage_done',
    'dva rolling_average_stats barrier_damage_done',
    'dva rolling_average_stats critical_hits',
    'dva rolling_average_stats damage_blocked',
    'dva rolling_average_stats deaths',
    'dva rolling_average_stats eliminations',
    'dva rolling_average_stats final_blows',
    'dva rolling_average_stats healing_done',
    'dva rolling_average_stats hero_damage_done',
    'dva rolling_average_stats mechs_called',
    'dva rolling_average_stats melee_final_blows',
    'dva rolling_average_stats objective_kills',
    'dva rolling_average_stats objective_time',
    'dva rolling_average_stats self_destruct_kills',
    'dva rolling_average_stats self_healing',
    'dva rolling_average_stats solo_kills',
    'dva rolling_average_stats time_spent_on_fire',
    'genji average_stats average_energy',
    'genji general_stats all_damage_done',
    'genji general_stats all_damage_done_most_in_game',
    'genji general_stats all_damage_done_most_in_life',
    'genji general_stats barrier_damage_done',
    'genji general_stats barrier_damage_done_most_in_game',
    'genji general_stats card',
    'genji general_stats cards',
    'genji general_stats critical_hit',
    'genji general_stats critical_hit_accuracy',
    'genji general_stats critical_hit_most_in_game',
    'genji general_stats critical_hit_most_in_life',
    'genji general_stats critical_hits',
    'genji general_stats critical_hits_most_in_game',
    'genji general_stats critical_hits_most_in_life',
    'genji general_stats death',
    'genji general_stats deaths',
    'genji general_stats elimination',
    'genji general_stats elimination_most_in_game',
    'genji general_stats elimination_most_in_life',
    'genji general_stats elimination_per_life',
    'genji general_stats eliminations',
    'genji general_stats eliminations_most_in_game',
    'genji general_stats eliminations_most_in_life',
    'genji general_stats eliminations_per_life',
    'genji general_stats environmental_kill',
    'genji general_stats environmental_kills',
    'genji general_stats final_blow',
    'genji general_stats final_blow_most_in_game',
    'genji general_stats final_blows',
    'genji general_stats final_blows_most_in_game',
    'genji general_stats games_lost',
    'genji general_stats games_played',
    'genji general_stats games_tied',
    'genji general_stats games_won',
    'genji general_stats hero_damage_done',
    'genji general_stats hero_damage_done_most_in_game',
    'genji general_stats hero_damage_done_most_in_life',
    'genji general_stats kill_streak_best',
    'genji general_stats medals',
    'genji general_stats medals_bronze',
    'genji general_stats medals_gold',
    'genji general_stats medals_silver',
    'genji general_stats melee_final_blow',
    'genji general_stats melee_final_blow_most_in_game',
    'genji general_stats melee_final_blows',
    'genji general_stats melee_final_blows_most_in_game',
    'genji general_stats multikill',
    'genji general_stats multikill_best',
    'genji general_stats multikills',
    'genji general_stats objective_kill',
    'genji general_stats objective_kill_most_in_game',
    'genji general_stats objective_kills',
    'genji general_stats objective_kills_most_in_game',
    'genji general_stats objective_time',
    'genji general_stats objective_time_most_in_game',
    'genji general_stats overwatchguid0x0860000000000033',
    'genji general_stats quick_melee_accuracy',
    'genji general_stats shield_generator_destroyed',
    'genji general_stats shield_generators_destroyed',
    'genji general_stats solo_kill',
    'genji general_stats solo_kill_most_in_game',
    'genji general_stats solo_kills',
    'genji general_stats solo_kills_most_in_game',
    'genji general_stats teleporter_pad_destroyed',
    'genji general_stats teleporter_pads_destroyed',
    'genji general_stats time_played',
    'genji general_stats time_spent_on_fire',
    'genji general_stats time_spent_on_fire_most_in_game',
    'genji general_stats turret_destroyed',
    'genji general_stats turrets_destroyed',
    'genji general_stats weapon_accuracy',
    'genji general_stats weapon_accuracy_best_in_game',
    'genji general_stats win_percentage',
    'genji hero_stats damage_reflected',
    'genji hero_stats damage_reflected_most_in_game',
    'genji hero_stats dragonblade',
    'genji hero_stats dragonblade_kill',
    'genji hero_stats dragonblade_kill_most_in_game',
    'genji hero_stats dragonblade_kills',
    'genji hero_stats dragonblade_kills_most_in_game',
    'genji hero_stats dragonblades',
    'genji rolling_average_stats all_damage_done',
    'genji rolling_average_stats barrier_damage_done',
    'genji rolling_average_stats critical_hits',
    'genji rolling_average_stats damage_reflected',
    'genji rolling_average_stats deaths',
    'genji rolling_average_stats dragonblade_kills',
    'genji rolling_average_stats eliminations',
    'genji rolling_average_stats final_blows',
    'genji rolling_average_stats hero_damage_done',
    'genji rolling_average_stats melee_final_blows',
    'genji rolling_average_stats objective_kills',
    'genji rolling_average_stats objective_time',
    'genji rolling_average_stats solo_kills',
    'genji rolling_average_stats time_spent_on_fire',
    'hanzo general_stats all_damage_done',
    'hanzo general_stats all_damage_done_most_in_game',
    'hanzo general_stats all_damage_done_most_in_life',
    'hanzo general_stats barrier_damage_done',
    'hanzo general_stats barrier_damage_done_most_in_game',
    'hanzo general_stats card',
    'hanzo general_stats cards',
    'hanzo general_stats critical_hit',
    'hanzo general_stats critical_hit_accuracy',
    'hanzo general_stats critical_hit_most_in_game',
    'hanzo general_stats critical_hit_most_in_life',
    'hanzo general_stats critical_hits',
    'hanzo general_stats critical_hits_most_in_game',
    'hanzo general_stats critical_hits_most_in_life',
    'hanzo general_stats death',
    'hanzo general_stats deaths',
    'hanzo general_stats elimination',
    'hanzo general_stats elimination_most_in_game',
    'hanzo general_stats elimination_most_in_life',
    'hanzo general_stats elimination_per_life',
    'hanzo general_stats eliminations',
    'hanzo general_stats eliminations_most_in_game',
    'hanzo general_stats eliminations_most_in_life',
    'hanzo general_stats eliminations_per_life',
    'hanzo general_stats environmental_kill',
    'hanzo general_stats final_blow',
    'hanzo general_stats final_blow_most_in_game',
    'hanzo general_stats final_blows',
    'hanzo general_stats final_blows_most_in_game',
    'hanzo general_stats game_lost',
    'hanzo general_stats game_played',
    'hanzo general_stats games_lost',
    'hanzo general_stats games_played',
    'hanzo general_stats games_tied',
    'hanzo general_stats games_won',
    'hanzo general_stats healing_done',
    'hanzo general_stats hero_damage_done',
    'hanzo general_stats hero_damage_done_most_in_game',
    'hanzo general_stats hero_damage_done_most_in_life',
    'hanzo general_stats kill_streak_best',
    'hanzo general_stats medals',
    'hanzo general_stats medals_bronze',
    'hanzo general_stats medals_gold',
    'hanzo general_stats medals_silver',
    'hanzo general_stats melee_final_blow',
    'hanzo general_stats melee_final_blow_most_in_game',
    'hanzo general_stats melee_final_blows',
    'hanzo general_stats melee_final_blows_most_in_game',
    'hanzo general_stats multikill',
    'hanzo general_stats multikill_best',
    'hanzo general_stats multikills',
    'hanzo general_stats objective_kill',
    'hanzo general_stats objective_kill_most_in_game',
    'hanzo general_stats objective_kills',
    'hanzo general_stats objective_kills_most_in_game',
    'hanzo general_stats objective_time',
    'hanzo general_stats objective_time_most_in_game',
    'hanzo general_stats overwatchguid0x0860000000000033',
    'hanzo general_stats quick_melee_accuracy',
    'hanzo general_stats recon_assist',
    'hanzo general_stats recon_assist_most_in_game',
    'hanzo general_stats recon_assists',
    'hanzo general_stats recon_assists_most_in_game',
    'hanzo general_stats shield_generator_destroyed',
    'hanzo general_stats shield_generators_destroyed',
    'hanzo general_stats solo_kill',
    'hanzo general_stats solo_kill_most_in_game',
    'hanzo general_stats solo_kills',
    'hanzo general_stats solo_kills_most_in_game',
    'hanzo general_stats teleporter_pad_destroyed',
    'hanzo general_stats teleporter_pads_destroyed',
    'hanzo general_stats time_played',
    'hanzo general_stats time_spent_on_fire',
    'hanzo general_stats time_spent_on_fire_most_in_game',
    'hanzo general_stats turret_destroyed',
    'hanzo general_stats turrets_destroyed',
    'hanzo general_stats weapon_accuracy',
    'hanzo general_stats weapon_accuracy_best_in_game',
    'hanzo general_stats win_percentage',
    'hanzo hero_stats dragonstrike_kill',
    'hanzo hero_stats dragonstrike_kill_most_in_game',
    'hanzo hero_stats dragonstrike_kills',
    'hanzo hero_stats dragonstrike_kills_most_in_game',
    'hanzo hero_stats scatter_arrow_kill',
    'hanzo hero_stats scatter_arrow_kill_most_in_game',
    'hanzo hero_stats scatter_arrow_kills',
    'hanzo hero_stats scatter_arrow_kills_most_in_game',
    'hanzo rolling_average_stats all_damage_done',
    'hanzo rolling_average_stats barrier_damage_done',
    'hanzo rolling_average_stats critical_hits',
    'hanzo rolling_average_stats deaths',
    'hanzo rolling_average_stats dragonstrike_kills',
    'hanzo rolling_average_stats eliminations',
    'hanzo rolling_average_stats final_blows',
    'hanzo rolling_average_stats healing_done',
    'hanzo rolling_average_stats hero_damage_done',
    'hanzo rolling_average_stats melee_final_blows',
    'hanzo rolling_average_stats objective_kills',
    'hanzo rolling_average_stats objective_time',
    'hanzo rolling_average_stats recon_assists',
    'hanzo rolling_average_stats scatter_arrow_kills',
    'hanzo rolling_average_stats solo_kills',
    'hanzo rolling_average_stats time_spent_on_fire',
    'junkrat average_stats average_energy',
    'junkrat general_stats all_damage_done',
    'junkrat general_stats all_damage_done_most_in_game',
    'junkrat general_stats all_damage_done_most_in_life',
    'junkrat general_stats barrier_damage_done',
    'junkrat general_stats barrier_damage_done_most_in_game',
    'junkrat general_stats card',
    'junkrat general_stats cards',
    'junkrat general_stats death',
    'junkrat general_stats deaths',
    'junkrat general_stats elimination',
    'junkrat general_stats elimination_most_in_game',
    'junkrat general_stats elimination_most_in_life',
    'junkrat general_stats elimination_per_life',
    'junkrat general_stats eliminations',
    'junkrat general_stats eliminations_most_in_game',
    'junkrat general_stats eliminations_most_in_life',
    'junkrat general_stats eliminations_per_life',
    'junkrat general_stats environmental_kill',
    'junkrat general_stats environmental_kills',
    'junkrat general_stats final_blow',
    'junkrat general_stats final_blow_most_in_game',
    'junkrat general_stats final_blows',
    'junkrat general_stats final_blows_most_in_game',
    'junkrat general_stats games_lost',
    'junkrat general_stats games_played',
    'junkrat general_stats games_tied',
    'junkrat general_stats games_won',
    'junkrat general_stats hero_damage_done',
    'junkrat general_stats hero_damage_done_most_in_game',
    'junkrat general_stats hero_damage_done_most_in_life',
    'junkrat general_stats kill_streak_best',
    'junkrat general_stats medals',
    'junkrat general_stats medals_bronze',
    'junkrat general_stats medals_gold',
    'junkrat general_stats medals_silver',
    'junkrat general_stats melee_final_blow',
    'junkrat general_stats melee_final_blow_most_in_game',
    'junkrat general_stats melee_final_blows',
    'junkrat general_stats melee_final_blows_most_in_game',
    'junkrat general_stats multikill',
    'junkrat general_stats multikill_best',
    'junkrat general_stats multikills',
    'junkrat general_stats objective_kill',
    'junkrat general_stats objective_kill_most_in_game',
    'junkrat general_stats objective_kills',
    'junkrat general_stats objective_kills_most_in_game',
    'junkrat general_stats objective_time',
    'junkrat general_stats objective_time_most_in_game',
    'junkrat general_stats offensive_assist',
    'junkrat general_stats offensive_assist_most_in_game',
    'junkrat general_stats offensive_assists',
    'junkrat general_stats offensive_assists_most_in_game',
    'junkrat general_stats quick_melee_accuracy',
    'junkrat general_stats shield_generator_destroyed',
    'junkrat general_stats shield_generators_destroyed',
    'junkrat general_stats solo_kill',
    'junkrat general_stats solo_kill_most_in_game',
    'junkrat general_stats solo_kills',
    'junkrat general_stats solo_kills_most_in_game',
    'junkrat general_stats teleporter_pad_destroyed',
    'junkrat general_stats teleporter_pads_destroyed',
    'junkrat general_stats time_played',
    'junkrat general_stats time_spent_on_fire',
    'junkrat general_stats time_spent_on_fire_most_in_game',
    'junkrat general_stats turret_destroyed',
    'junkrat general_stats turrets_destroyed',
    'junkrat general_stats weapon_accuracy',
    'junkrat general_stats weapon_accuracy_best_in_game',
    'junkrat general_stats win_percentage',
    'junkrat hero_stats concussion_mine_kill',
    'junkrat hero_stats concussion_mine_kill_most_in_game',
    'junkrat hero_stats concussion_mine_kills',
    'junkrat hero_stats concussion_mine_kills_most_in_game',
    'junkrat hero_stats enemies_trapped',
    'junkrat hero_stats enemies_trapped_most_in_game',
    'junkrat hero_stats enemy_trapped',
    'junkrat hero_stats enemy_trapped_most_in_game',
    'junkrat hero_stats rip_tire_kill',
    'junkrat hero_stats rip_tire_kill_most_in_game',
    'junkrat hero_stats rip_tire_kills',
    'junkrat hero_stats rip_tire_kills_most_in_game',
    'junkrat rolling_average_stats all_damage_done',
    'junkrat rolling_average_stats barrier_damage_done',
    'junkrat rolling_average_stats concussion_mine_kills',
    'junkrat rolling_average_stats deaths',
    'junkrat rolling_average_stats eliminations',
    'junkrat rolling_average_stats enemies_trapped',
    'junkrat rolling_average_stats final_blows',
    'junkrat rolling_average_stats hero_damage_done',
    'junkrat rolling_average_stats melee_final_blows',
    'junkrat rolling_average_stats objective_kills',
    'junkrat rolling_average_stats objective_time',
    'junkrat rolling_average_stats offensive_assists',
    'junkrat rolling_average_stats rip_tire_kills',
    'junkrat rolling_average_stats solo_kills',
    'junkrat rolling_average_stats time_spent_on_fire',
    'lucio average_stats average_energy',
    'lucio average_stats teleporter_uptime_average',
    'lucio general_stats all_damage_done',
    'lucio general_stats all_damage_done_most_in_game',
    'lucio general_stats all_damage_done_most_in_life',
    'lucio general_stats barrier_damage_done',
    'lucio general_stats barrier_damage_done_most_in_game',
    'lucio general_stats card',
    'lucio general_stats cards',
    'lucio general_stats critical_hit',
    'lucio general_stats critical_hit_accuracy',
    'lucio general_stats critical_hit_most_in_game',
    'lucio general_stats critical_hit_most_in_life',
    'lucio general_stats critical_hits',
    'lucio general_stats critical_hits_most_in_game',
    'lucio general_stats critical_hits_most_in_life',
    'lucio general_stats death',
    'lucio general_stats deaths',
    'lucio general_stats defensive_assist',
    'lucio general_stats defensive_assist_most_in_game',
    'lucio general_stats defensive_assists',
    'lucio general_stats defensive_assists_most_in_game',
    'lucio general_stats elimination',
    'lucio general_stats elimination_most_in_game',
    'lucio general_stats elimination_most_in_life',
    'lucio general_stats elimination_per_life',
    'lucio general_stats eliminations',
    'lucio general_stats eliminations_most_in_game',
    'lucio general_stats eliminations_most_in_life',
    'lucio general_stats eliminations_per_life',
    'lucio general_stats environmental_kill',
    'lucio general_stats environmental_kills',
    'lucio general_stats final_blow',
    'lucio general_stats final_blow_most_in_game',
    'lucio general_stats final_blows',
    'lucio general_stats final_blows_most_in_game',
    'lucio general_stats games_lost',
    'lucio general_stats games_played',
    'lucio general_stats games_tied',
    'lucio general_stats games_won',
    'lucio general_stats healing_done',
    'lucio general_stats healing_done_most_in_game',
    'lucio general_stats hero_damage_done',
    'lucio general_stats hero_damage_done_most_in_game',
    'lucio general_stats hero_damage_done_most_in_life',
    'lucio general_stats kill_streak_best',
    'lucio general_stats medals',
    'lucio general_stats medals_bronze',
    'lucio general_stats medals_gold',
    'lucio general_stats medals_silver',
    'lucio general_stats melee_final_blow',
    'lucio general_stats melee_final_blow_most_in_game',
    'lucio general_stats melee_final_blows',
    'lucio general_stats melee_final_blows_most_in_game',
    'lucio general_stats multikill',
    'lucio general_stats multikill_best',
    'lucio general_stats multikills',
    'lucio general_stats objective_kill',
    'lucio general_stats objective_kill_most_in_game',
    'lucio general_stats objective_kills',
    'lucio general_stats objective_kills_most_in_game',
    'lucio general_stats objective_time',
    'lucio general_stats objective_time_most_in_game',
    'lucio general_stats offensive_assist',
    'lucio general_stats offensive_assist_most_in_game',
    'lucio general_stats offensive_assists',
    'lucio general_stats offensive_assists_most_in_game',
    'lucio general_stats overwatchguid0x0860000000000033',
    'lucio general_stats quick_melee_accuracy',
    'lucio general_stats shield_generator_destroyed',
    'lucio general_stats shield_generators_destroyed',
    'lucio general_stats solo_kill',
    'lucio general_stats solo_kill_most_in_game',
    'lucio general_stats solo_kills',
    'lucio general_stats solo_kills_most_in_game',
    'lucio general_stats teleporter_pad_destroyed',
    'lucio general_stats teleporter_pads_destroyed',
    'lucio general_stats time_played',
    'lucio general_stats time_spent_on_fire',
    'lucio general_stats time_spent_on_fire_most_in_game',
    'lucio general_stats turret_destroyed',
    'lucio general_stats turrets_destroyed',
    'lucio general_stats weapon_accuracy',
    'lucio general_stats weapon_accuracy_best_in_game',
    'lucio general_stats win_percentage',
    'lucio hero_stats enemies_frozen',
    'lucio hero_stats self_healing',
    'lucio hero_stats self_healing_most_in_game',
    'lucio hero_stats sentry_turret_kills',
    'lucio hero_stats sound_barrier_provided',
    'lucio hero_stats sound_barrier_provided_most_in_game',
    'lucio hero_stats sound_barriers_provided',
    'lucio hero_stats sound_barriers_provided_most_in_game',
    'lucio hero_stats teleporter_uptime',
    'lucio hero_stats turret_kills',
    'lucio rolling_average_stats all_damage_done',
    'lucio rolling_average_stats barrier_damage_done',
    'lucio rolling_average_stats critical_hits',
    'lucio rolling_average_stats deaths',
    'lucio rolling_average_stats defensive_assists',
    'lucio rolling_average_stats eliminations',
    'lucio rolling_average_stats enemies_frozen',
    'lucio rolling_average_stats final_blows',
    'lucio rolling_average_stats healing_done',
    'lucio rolling_average_stats hero_damage_done',
    'lucio rolling_average_stats melee_final_blows',
    'lucio rolling_average_stats objective_kills',
    'lucio rolling_average_stats objective_time',
    'lucio rolling_average_stats offensive_assists',
    'lucio rolling_average_stats self_healing',
    'lucio rolling_average_stats sentry_turret_kills',
    'lucio rolling_average_stats solo_kills',
    'lucio rolling_average_stats sound_barriers_provided',
    'lucio rolling_average_stats time_spent_on_fire',
    'mccree general_stats all_damage_done',
    'mccree general_stats all_damage_done_most_in_game',
    'mccree general_stats all_damage_done_most_in_life',
    'mccree general_stats barrier_damage_done',
    'mccree general_stats barrier_damage_done_most_in_game',
    'mccree general_stats card',
    'mccree general_stats cards',
    'mccree general_stats critical_hit',
    'mccree general_stats critical_hit_accuracy',
    'mccree general_stats critical_hit_most_in_game',
    'mccree general_stats critical_hit_most_in_life',
    'mccree general_stats critical_hits',
    'mccree general_stats critical_hits_most_in_game',
    'mccree general_stats critical_hits_most_in_life',
    'mccree general_stats death',
    'mccree general_stats deaths',
    'mccree general_stats elimination',
    'mccree general_stats elimination_most_in_game',
    'mccree general_stats elimination_most_in_life',
    'mccree general_stats elimination_per_life',
    'mccree general_stats eliminations',
    'mccree general_stats eliminations_most_in_game',
    'mccree general_stats eliminations_most_in_life',
    'mccree general_stats eliminations_per_life',
    'mccree general_stats environmental_kill',
    'mccree general_stats final_blow',
    'mccree general_stats final_blow_most_in_game',
    'mccree general_stats final_blows',
    'mccree general_stats final_blows_most_in_game',
    'mccree general_stats games_lost',
    'mccree general_stats games_played',
    'mccree general_stats games_tied',
    'mccree general_stats games_won',
    'mccree general_stats hero_damage_done',
    'mccree general_stats hero_damage_done_most_in_game',
    'mccree general_stats hero_damage_done_most_in_life',
    'mccree general_stats kill_streak_best',
    'mccree general_stats medals',
    'mccree general_stats medals_bronze',
    'mccree general_stats medals_gold',
    'mccree general_stats medals_silver',
    'mccree general_stats melee_final_blow',
    'mccree general_stats melee_final_blow_most_in_game',
    'mccree general_stats melee_final_blows',
    'mccree general_stats melee_final_blows_most_in_game',
    'mccree general_stats multikill',
    'mccree general_stats multikill_best',
    'mccree general_stats multikills',
    'mccree general_stats objective_kill',
    'mccree general_stats objective_kill_most_in_game',
    'mccree general_stats objective_kills',
    'mccree general_stats objective_kills_most_in_game',
    'mccree general_stats objective_time',
    'mccree general_stats objective_time_most_in_game',
    'mccree general_stats offensive_assist_most_in_game',
    'mccree general_stats offensive_assists_most_in_game',
    'mccree general_stats overwatchguid0x0860000000000033',
    'mccree general_stats quick_melee_accuracy',
    'mccree general_stats shield_generator_destroyed',
    'mccree general_stats shield_generators_destroyed',
    'mccree general_stats solo_kill',
    'mccree general_stats solo_kill_most_in_game',
    'mccree general_stats solo_kills',
    'mccree general_stats solo_kills_most_in_game',
    'mccree general_stats teleporter_pad_destroyed',
    'mccree general_stats teleporter_pads_destroyed',
    'mccree general_stats time_played',
    'mccree general_stats time_spent_on_fire',
    'mccree general_stats time_spent_on_fire_most_in_game',
    'mccree general_stats turret_destroyed',
    'mccree general_stats turrets_destroyed',
    'mccree general_stats weapon_accuracy',
    'mccree general_stats weapon_accuracy_best_in_game',
    'mccree general_stats win_percentage',
    'mccree hero_stats deadeye_kill',
    'mccree hero_stats deadeye_kill_most_in_game',
    'mccree hero_stats deadeye_kills',
    'mccree hero_stats deadeye_kills_most_in_game',
    'mccree hero_stats fan_the_hammer_kill',
    'mccree hero_stats fan_the_hammer_kill_most_in_game',
    'mccree hero_stats fan_the_hammer_kills',
    'mccree hero_stats fan_the_hammer_kills_most_in_game',
    'mccree rolling_average_stats all_damage_done',
    'mccree rolling_average_stats barrier_damage_done',
    'mccree rolling_average_stats critical_hits',
    'mccree rolling_average_stats deadeye_kills',
    'mccree rolling_average_stats deaths',
    'mccree rolling_average_stats eliminations',
    'mccree rolling_average_stats fan_the_hammer_kills',
    'mccree rolling_average_stats final_blows',
    'mccree rolling_average_stats hero_damage_done',
    'mccree rolling_average_stats melee_final_blows',
    'mccree rolling_average_stats objective_kills',
    'mccree rolling_average_stats objective_time',
    'mccree rolling_average_stats solo_kills',
    'mccree rolling_average_stats time_spent_on_fire',
    'mei general_stats all_damage_done',
    'mei general_stats all_damage_done_most_in_game',
    'mei general_stats all_damage_done_most_in_life',
    'mei general_stats barrier_damage_done',
    'mei general_stats barrier_damage_done_most_in_game',
    'mei general_stats card',
    'mei general_stats cards',
    'mei general_stats critical_hit',
    'mei general_stats critical_hit_accuracy',
    'mei general_stats critical_hit_most_in_game',
    'mei general_stats critical_hit_most_in_life',
    'mei general_stats critical_hits',
    'mei general_stats critical_hits_most_in_game',
    'mei general_stats critical_hits_most_in_life',
    'mei general_stats death',
    'mei general_stats deaths',
    'mei general_stats elimination',
    'mei general_stats elimination_most_in_game',
    'mei general_stats elimination_most_in_life',
    'mei general_stats elimination_per_life',
    'mei general_stats eliminations',
    'mei general_stats eliminations_most_in_game',
    'mei general_stats eliminations_most_in_life',
    'mei general_stats eliminations_per_life',
    'mei general_stats environmental_kill',
    'mei general_stats final_blow',
    'mei general_stats final_blow_most_in_game',
    'mei general_stats final_blows',
    'mei general_stats final_blows_most_in_game',
    'mei general_stats games_lost',
    'mei general_stats games_played',
    'mei general_stats games_tied',
    'mei general_stats games_won',
    'mei general_stats healing_done',
    'mei general_stats hero_damage_done',
    'mei general_stats hero_damage_done_most_in_game',
    'mei general_stats hero_damage_done_most_in_life',
    'mei general_stats kill_streak_best',
    'mei general_stats medals',
    'mei general_stats medals_bronze',
    'mei general_stats medals_gold',
    'mei general_stats medals_silver',
    'mei general_stats melee_final_blow',
    'mei general_stats melee_final_blow_most_in_game',
    'mei general_stats melee_final_blows',
    'mei general_stats melee_final_blows_most_in_game',
    'mei general_stats multikill',
    'mei general_stats multikill_best',
    'mei general_stats multikills',
    'mei general_stats objective_kill',
    'mei general_stats objective_kill_most_in_game',
    'mei general_stats objective_kills',
    'mei general_stats objective_kills_most_in_game',
    'mei general_stats objective_time',
    'mei general_stats objective_time_most_in_game',
    'mei general_stats offensive_assist',
    'mei general_stats offensive_assist_most_in_game',
    'mei general_stats offensive_assists',
    'mei general_stats offensive_assists_most_in_game',
    'mei general_stats overwatchguid0x0860000000000033',
    'mei general_stats quick_melee_accuracy',
    'mei general_stats shield_generator_destroyed',
    'mei general_stats shield_generators_destroyed',
    'mei general_stats solo_kill',
    'mei general_stats solo_kill_most_in_game',
    'mei general_stats solo_kills',
    'mei general_stats solo_kills_most_in_game',
    'mei general_stats teleporter_pad_destroyed',
    'mei general_stats teleporter_pads_destroyed',
    'mei general_stats time_played',
    'mei general_stats time_spent_on_fire',
    'mei general_stats time_spent_on_fire_most_in_game',
    'mei general_stats turret_destroyed',
    'mei general_stats turrets_destroyed',
    'mei general_stats weapon_accuracy',
    'mei general_stats weapon_accuracy_best_in_game',
    'mei general_stats win_percentage',
    'mei hero_stats biotic_field_healing_done',
    'mei hero_stats blizzard_kill',
    'mei hero_stats blizzard_kill_most_in_game',
    'mei hero_stats blizzard_kills',
    'mei hero_stats blizzard_kills_most_in_game',
    'mei hero_stats damage_blocked',
    'mei hero_stats damage_blocked_most_in_game',
    'mei hero_stats enemies_frozen',
    'mei hero_stats enemies_frozen_most_in_game',
    'mei hero_stats enemy_frozen',
    'mei hero_stats enemy_frozen_most_in_game',
    'mei hero_stats self_healing',
    'mei hero_stats self_healing_most_in_game',
    'mei rolling_average_stats all_damage_done',
    'mei rolling_average_stats barrier_damage_done',
    'mei rolling_average_stats blizzard_kills',
    'mei rolling_average_stats critical_hits',
    'mei rolling_average_stats damage_blocked',
    'mei rolling_average_stats deaths',
    'mei rolling_average_stats eliminations',
    'mei rolling_average_stats enemies_frozen',
    'mei rolling_average_stats final_blows',
    'mei rolling_average_stats healing_done',
    'mei rolling_average_stats hero_damage_done',
    'mei rolling_average_stats melee_final_blows',
    'mei rolling_average_stats objective_kills',
    'mei rolling_average_stats objective_time',
    'mei rolling_average_stats offensive_assists',
    'mei rolling_average_stats self_healing',
    'mei rolling_average_stats solo_kills',
    'mei rolling_average_stats time_spent_on_fire',
    'mercy average_stats average_energy',
    'mercy average_stats teleporter_uptime_average',
    'mercy general_stats all_damage_done',
    'mercy general_stats all_damage_done_most_in_game',
    'mercy general_stats all_damage_done_most_in_life',
    'mercy general_stats barrier_damage_done',
    'mercy general_stats barrier_damage_done_most_in_game',
    'mercy general_stats card',
    'mercy general_stats cards',
    'mercy general_stats critical_hit',
    'mercy general_stats critical_hit_accuracy',
    'mercy general_stats critical_hit_most_in_game',
    'mercy general_stats critical_hit_most_in_life',
    'mercy general_stats critical_hits',
    'mercy general_stats critical_hits_most_in_game',
    'mercy general_stats critical_hits_most_in_life',
    'mercy general_stats death',
    'mercy general_stats deaths',
    'mercy general_stats defensive_assist',
    'mercy general_stats defensive_assist_most_in_game',
    'mercy general_stats defensive_assists',
    'mercy general_stats defensive_assists_most_in_game',
    'mercy general_stats elimination',
    'mercy general_stats elimination_most_in_game',
    'mercy general_stats elimination_most_in_life',
    'mercy general_stats elimination_per_life',
    'mercy general_stats eliminations',
    'mercy general_stats eliminations_most_in_game',
    'mercy general_stats eliminations_most_in_life',
    'mercy general_stats eliminations_per_life',
    'mercy general_stats environmental_kill',
    'mercy general_stats final_blow',
    'mercy general_stats final_blow_most_in_game',
    'mercy general_stats final_blows',
    'mercy general_stats final_blows_most_in_game',
    'mercy general_stats games_lost',
    'mercy general_stats games_played',
    'mercy general_stats games_tied',
    'mercy general_stats games_won',
    'mercy general_stats healing_done',
    'mercy general_stats healing_done_most_in_game',
    'mercy general_stats hero_damage_done',
    'mercy general_stats hero_damage_done_most_in_game',
    'mercy general_stats hero_damage_done_most_in_life',
    'mercy general_stats kill_streak_best',
    'mercy general_stats medals',
    'mercy general_stats medals_bronze',
    'mercy general_stats medals_gold',
    'mercy general_stats medals_silver',
    'mercy general_stats melee_final_blow',
    'mercy general_stats melee_final_blow_most_in_game',
    'mercy general_stats melee_final_blows',
    'mercy general_stats melee_final_blows_most_in_game',
    'mercy general_stats multikill',
    'mercy general_stats multikill_best',
    'mercy general_stats multikills',
    'mercy general_stats objective_kill',
    'mercy general_stats objective_kill_most_in_game',
    'mercy general_stats objective_kills',
    'mercy general_stats objective_kills_most_in_game',
    'mercy general_stats objective_time',
    'mercy general_stats objective_time_most_in_game',
    'mercy general_stats offensive_assist',
    'mercy general_stats offensive_assist_most_in_game',
    'mercy general_stats offensive_assists',
    'mercy general_stats offensive_assists_most_in_game',
    'mercy general_stats overwatchguid0x0860000000000033',
    'mercy general_stats quick_melee_accuracy',
    'mercy general_stats shield_generator_destroyed',
    'mercy general_stats shield_generators_destroyed',
    'mercy general_stats solo_kill',
    'mercy general_stats solo_kill_most_in_game',
    'mercy general_stats solo_kills',
    'mercy general_stats solo_kills_most_in_game',
    'mercy general_stats teleporter_pad_destroyed',
    'mercy general_stats teleporter_pads_destroyed',
    'mercy general_stats time_played',
    'mercy general_stats time_spent_on_fire',
    'mercy general_stats time_spent_on_fire_most_in_game',
    'mercy general_stats turret_destroyed',
    'mercy general_stats turrets_destroyed',
    'mercy general_stats weapon_accuracy',
    'mercy general_stats weapon_accuracy_best_in_game',
    'mercy general_stats win_percentage',
    'mercy hero_stats blaster_kill',
    'mercy hero_stats blaster_kill_most_in_game',
    'mercy hero_stats blaster_kills',
    'mercy hero_stats blaster_kills_most_in_game',
    'mercy hero_stats damage_amplified',
    'mercy hero_stats damage_amplified_most_in_game',
    'mercy hero_stats player_resurrected',
    'mercy hero_stats player_resurrected_most_in_game',
    'mercy hero_stats players_resurrected',
    'mercy hero_stats players_resurrected_most_in_game',
    'mercy hero_stats self_healing',
    'mercy hero_stats self_healing_most_in_game',
    'mercy hero_stats teleporter_uptime',
    'mercy rolling_average_stats all_damage_done',
    'mercy rolling_average_stats barrier_damage_done',
    'mercy rolling_average_stats blaster_kills',
    'mercy rolling_average_stats critical_hits',
    'mercy rolling_average_stats damage_amplified',
    'mercy rolling_average_stats deaths',
    'mercy rolling_average_stats defensive_assists',
    'mercy rolling_average_stats eliminations',
    'mercy rolling_average_stats final_blows',
    'mercy rolling_average_stats healing_done',
    'mercy rolling_average_stats hero_damage_done',
    'mercy rolling_average_stats melee_final_blows',
    'mercy rolling_average_stats objective_kills',
    'mercy rolling_average_stats objective_time',
    'mercy rolling_average_stats offensive_assists',
    'mercy rolling_average_stats players_resurrected',
    'mercy rolling_average_stats self_healing',
    'mercy rolling_average_stats solo_kills',
    'mercy rolling_average_stats time_spent_on_fire',
    'moira general_stats all_damage_done',
    'moira general_stats all_damage_done_most_in_game',
    'moira general_stats all_damage_done_most_in_life',
    'moira general_stats barrier_damage_done',
    'moira general_stats barrier_damage_done_most_in_game',
    'moira general_stats card',
    'moira general_stats cards',
    'moira general_stats death',
    'moira general_stats deaths',
    'moira general_stats defensive_assist',
    'moira general_stats defensive_assist_most_in_game',
    'moira general_stats defensive_assists',
    'moira general_stats defensive_assists_most_in_game',
    'moira general_stats elimination',
    'moira general_stats elimination_most_in_game',
    'moira general_stats elimination_most_in_life',
    'moira general_stats elimination_per_life',
    'moira general_stats eliminations',
    'moira general_stats eliminations_most_in_game',
    'moira general_stats eliminations_most_in_life',
    'moira general_stats eliminations_per_life',
    'moira general_stats environmental_kill',
    'moira general_stats environmental_kills',
    'moira general_stats final_blow',
    'moira general_stats final_blow_most_in_game',
    'moira general_stats final_blows',
    'moira general_stats final_blows_most_in_game',
    'moira general_stats games_lost',
    'moira general_stats games_played',
    'moira general_stats games_tied',
    'moira general_stats games_won',
    'moira general_stats healing_done',
    'moira general_stats healing_done_most_in_game',
    'moira general_stats hero_damage_done',
    'moira general_stats hero_damage_done_most_in_game',
    'moira general_stats hero_damage_done_most_in_life',
    'moira general_stats kill_streak_best',
    'moira general_stats medals',
    'moira general_stats medals_bronze',
    'moira general_stats medals_gold',
    'moira general_stats medals_silver',
    'moira general_stats melee_final_blow',
    'moira general_stats melee_final_blow_most_in_game',
    'moira general_stats melee_final_blows',
    'moira general_stats melee_final_blows_most_in_game',
    'moira general_stats multikill',
    'moira general_stats multikill_best',
    'moira general_stats multikills',
    'moira general_stats objective_kill',
    'moira general_stats objective_kill_most_in_game',
    'moira general_stats objective_kills',
    'moira general_stats objective_kills_most_in_game',
    'moira general_stats objective_time',
    'moira general_stats objective_time_most_in_game',
    'moira general_stats quick_melee_accuracy',
    'moira general_stats shield_generator_destroyed',
    'moira general_stats shield_generators_destroyed',
    'moira general_stats solo_kill',
    'moira general_stats solo_kill_most_in_game',
    'moira general_stats solo_kills',
    'moira general_stats solo_kills_most_in_game',
    'moira general_stats teleporter_pad_destroyed',
    'moira general_stats teleporter_pads_destroyed',
    'moira general_stats time_played',
    'moira general_stats time_spent_on_fire',
    'moira general_stats time_spent_on_fire_most_in_game',
    'moira general_stats turret_destroyed',
    'moira general_stats turrets_destroyed',
    'moira general_stats win_percentage',
    'moira hero_stats coalescence_healing',
    'moira hero_stats coalescence_healing_most_in_game',
    'moira hero_stats coalescence_kill',
    'moira hero_stats coalescence_kill_most_in_game',
    'moira hero_stats coalescence_kills',
    'moira hero_stats coalescence_kills_most_in_game',
    'moira hero_stats secondary_fire_accuracy',
    'moira hero_stats self_healing',
    'moira hero_stats self_healing_most_in_game',
    'moira rolling_average_stats all_damage_done',
    'moira rolling_average_stats barrier_damage_done',
    'moira rolling_average_stats coalescence_healing',
    'moira rolling_average_stats coalescence_kills',
    'moira rolling_average_stats deaths',
    'moira rolling_average_stats defensive_assists',
    'moira rolling_average_stats eliminations',
    'moira rolling_average_stats final_blows',
    'moira rolling_average_stats healing_done',
    'moira rolling_average_stats hero_damage_done',
    'moira rolling_average_stats melee_final_blows',
    'moira rolling_average_stats objective_kills',
    'moira rolling_average_stats objective_time',
    'moira rolling_average_stats self_healing',
    'moira rolling_average_stats solo_kills',
    'moira rolling_average_stats time_spent_on_fire',
    'orisa general_stats all_damage_done',
    'orisa general_stats all_damage_done_most_in_game',
    'orisa general_stats all_damage_done_most_in_life',
    'orisa general_stats barrier_damage_done',
    'orisa general_stats barrier_damage_done_most_in_game',
    'orisa general_stats card',
    'orisa general_stats cards',
    'orisa general_stats death',
    'orisa general_stats deaths',
    'orisa general_stats elimination',
    'orisa general_stats elimination_most_in_game',
    'orisa general_stats elimination_most_in_life',
    'orisa general_stats elimination_per_life',
    'orisa general_stats eliminations',
    'orisa general_stats eliminations_most_in_game',
    'orisa general_stats eliminations_most_in_life',
    'orisa general_stats eliminations_per_life',
    'orisa general_stats environmental_kill',
    'orisa general_stats environmental_kills',
    'orisa general_stats final_blow',
    'orisa general_stats final_blow_most_in_game',
    'orisa general_stats final_blows',
    'orisa general_stats final_blows_most_in_game',
    'orisa general_stats games_lost',
    'orisa general_stats games_played',
    'orisa general_stats games_tied',
    'orisa general_stats games_won',
    'orisa general_stats hero_damage_done',
    'orisa general_stats hero_damage_done_most_in_game',
    'orisa general_stats hero_damage_done_most_in_life',
    'orisa general_stats kill_streak_best',
    'orisa general_stats medals',
    'orisa general_stats medals_bronze',
    'orisa general_stats medals_gold',
    'orisa general_stats medals_silver',
    'orisa general_stats melee_final_blow',
    'orisa general_stats melee_final_blow_most_in_game',
    'orisa general_stats melee_final_blows',
    'orisa general_stats melee_final_blows_most_in_game',
    'orisa general_stats multikill',
    'orisa general_stats multikill_best',
    'orisa general_stats multikills',
    'orisa general_stats objective_kill',
    'orisa general_stats objective_kill_most_in_game',
    'orisa general_stats objective_kills',
    'orisa general_stats objective_kills_most_in_game',
    'orisa general_stats objective_time',
    'orisa general_stats objective_time_most_in_game',
    'orisa general_stats offensive_assist',
    'orisa general_stats offensive_assist_most_in_game',
    'orisa general_stats offensive_assists',
    'orisa general_stats offensive_assists_most_in_game',
    'orisa general_stats overwatchguid0x0860000000000033',
    'orisa general_stats quick_melee_accuracy',
    'orisa general_stats shield_generator_destroyed',
    'orisa general_stats shield_generators_destroyed',
    'orisa general_stats solo_kill',
    'orisa general_stats solo_kill_most_in_game',
    'orisa general_stats solo_kills',
    'orisa general_stats solo_kills_most_in_game',
    'orisa general_stats teleporter_pad_destroyed',
    'orisa general_stats teleporter_pads_destroyed',
    'orisa general_stats time_played',
    'orisa general_stats time_spent_on_fire',
    'orisa general_stats time_spent_on_fire_most_in_game',
    'orisa general_stats turret_destroyed',
    'orisa general_stats turrets_destroyed',
    'orisa general_stats weapon_accuracy',
    'orisa general_stats weapon_accuracy_best_in_game',
    'orisa general_stats win_percentage',
    'orisa hero_stats damage_amplified',
    'orisa hero_stats damage_amplified_most_in_game',
    'orisa hero_stats damage_blocked',
    'orisa hero_stats damage_blocked_most_in_game',
    'orisa hero_stats supercharger_assist',
    'orisa hero_stats supercharger_assist_most_in_game',
    'orisa hero_stats supercharger_assists',
    'orisa hero_stats supercharger_assists_most_in_game',
    'orisa rolling_average_stats all_damage_done',
    'orisa rolling_average_stats barrier_damage_done',
    'orisa rolling_average_stats damage_amplified',
    'orisa rolling_average_stats damage_blocked',
    'orisa rolling_average_stats deaths',
    'orisa rolling_average_stats eliminations',
    'orisa rolling_average_stats final_blows',
    'orisa rolling_average_stats hero_damage_done',
    'orisa rolling_average_stats melee_final_blows',
    'orisa rolling_average_stats objective_kills',
    'orisa rolling_average_stats objective_time',
    'orisa rolling_average_stats offensive_assists',
    'orisa rolling_average_stats solo_kills',
    'orisa rolling_average_stats supercharger_assists',
    'orisa rolling_average_stats time_spent_on_fire',
    'pharah average_stats average_energy',
    'pharah general_stats all_damage_done',
    'pharah general_stats all_damage_done_most_in_game',
    'pharah general_stats all_damage_done_most_in_life',
    'pharah general_stats barrier_damage_done',
    'pharah general_stats barrier_damage_done_most_in_game',
    'pharah general_stats card',
    'pharah general_stats cards',
    'pharah general_stats death',
    'pharah general_stats deaths',
    'pharah general_stats elimination',
    'pharah general_stats elimination_most_in_game',
    'pharah general_stats elimination_most_in_life',
    'pharah general_stats elimination_per_life',
    'pharah general_stats eliminations',
    'pharah general_stats eliminations_most_in_game',
    'pharah general_stats eliminations_most_in_life',
    'pharah general_stats eliminations_per_life',
    'pharah general_stats environmental_kill',
    'pharah general_stats environmental_kills',
    'pharah general_stats final_blow',
    'pharah general_stats final_blow_most_in_game',
    'pharah general_stats final_blows',
    'pharah general_stats final_blows_most_in_game',
    'pharah general_stats games_lost',
    'pharah general_stats games_played',
    'pharah general_stats games_tied',
    'pharah general_stats games_won',
    'pharah general_stats healing_done',
    'pharah general_stats hero_damage_done',
    'pharah general_stats hero_damage_done_most_in_game',
    'pharah general_stats hero_damage_done_most_in_life',
    'pharah general_stats kill_streak_best',
    'pharah general_stats medals',
    'pharah general_stats medals_bronze',
    'pharah general_stats medals_gold',
    'pharah general_stats medals_silver',
    'pharah general_stats melee_final_blow',
    'pharah general_stats melee_final_blow_most_in_game',
    'pharah general_stats melee_final_blows',
    'pharah general_stats melee_final_blows_most_in_game',
    'pharah general_stats multikill',
    'pharah general_stats multikill_best',
    'pharah general_stats multikills',
    'pharah general_stats objective_kill',
    'pharah general_stats objective_kill_most_in_game',
    'pharah general_stats objective_kills',
    'pharah general_stats objective_kills_most_in_game',
    'pharah general_stats objective_time',
    'pharah general_stats objective_time_most_in_game',
    'pharah general_stats quick_melee_accuracy',
    'pharah general_stats shield_generator_destroyed',
    'pharah general_stats shield_generators_destroyed',
    'pharah general_stats solo_kill',
    'pharah general_stats solo_kill_most_in_game',
    'pharah general_stats solo_kills',
    'pharah general_stats solo_kills_most_in_game',
    'pharah general_stats teleporter_pad_destroyed',
    'pharah general_stats teleporter_pads_destroyed',
    'pharah general_stats time_played',
    'pharah general_stats time_spent_on_fire',
    'pharah general_stats time_spent_on_fire_most_in_game',
    'pharah general_stats turret_destroyed',
    'pharah general_stats turrets_destroyed',
    'pharah general_stats weapon_accuracy',
    'pharah general_stats weapon_accuracy_best_in_game',
    'pharah general_stats win_percentage',
    'pharah hero_stats barrage_kill',
    'pharah hero_stats barrage_kill_most_in_game',
    'pharah hero_stats barrage_kills',
    'pharah hero_stats barrage_kills_most_in_game',
    'pharah hero_stats enemy_frozen',
    'pharah hero_stats enemy_frozen_most_in_game',
    'pharah hero_stats rocket_direct_hit',
    'pharah hero_stats rocket_direct_hit_most_in_game',
    'pharah hero_stats rocket_direct_hits',
    'pharah hero_stats rocket_direct_hits_most_in_game',
    'pharah hero_stats self_healing',
    'pharah rolling_average_stats all_damage_done',
    'pharah rolling_average_stats barrage_kills',
    'pharah rolling_average_stats barrier_damage_done',
    'pharah rolling_average_stats deaths',
    'pharah rolling_average_stats eliminations',
    'pharah rolling_average_stats enemies_frozen',
    'pharah rolling_average_stats final_blows',
    'pharah rolling_average_stats healing_done',
    'pharah rolling_average_stats hero_damage_done',
    'pharah rolling_average_stats melee_final_blows',
    'pharah rolling_average_stats objective_kills',
    'pharah rolling_average_stats objective_time',
    'pharah rolling_average_stats rocket_direct_hits',
    'pharah rolling_average_stats self_healing',
    'pharah rolling_average_stats solo_kills',
    'pharah rolling_average_stats time_spent_on_fire',
    'reaper average_stats average_energy',
    'reaper average_stats teleporter_uptime_average',
    'reaper general_stats all_damage_done',
    'reaper general_stats all_damage_done_most_in_game',
    'reaper general_stats all_damage_done_most_in_life',
    'reaper general_stats barrier_damage_done',
    'reaper general_stats barrier_damage_done_most_in_game',
    'reaper general_stats card',
    'reaper general_stats cards',
    'reaper general_stats critical_hit',
    'reaper general_stats critical_hit_accuracy',
    'reaper general_stats critical_hit_most_in_game',
    'reaper general_stats critical_hit_most_in_life',
    'reaper general_stats critical_hits',
    'reaper general_stats critical_hits_most_in_game',
    'reaper general_stats critical_hits_most_in_life',
    'reaper general_stats death',
    'reaper general_stats deaths',
    'reaper general_stats elimination',
    'reaper general_stats elimination_most_in_game',
    'reaper general_stats elimination_most_in_life',
    'reaper general_stats elimination_per_life',
    'reaper general_stats eliminations',
    'reaper general_stats eliminations_most_in_game',
    'reaper general_stats eliminations_most_in_life',
    'reaper general_stats eliminations_per_life',
    'reaper general_stats environmental_kill',
    'reaper general_stats final_blow',
    'reaper general_stats final_blow_most_in_game',
    'reaper general_stats final_blows',
    'reaper general_stats final_blows_most_in_game',
    'reaper general_stats games_lost',
    'reaper general_stats games_played',
    'reaper general_stats games_tied',
    'reaper general_stats games_won',
    'reaper general_stats healing_done',
    'reaper general_stats hero_damage_done',
    'reaper general_stats hero_damage_done_most_in_game',
    'reaper general_stats hero_damage_done_most_in_life',
    'reaper general_stats kill_streak_best',
    'reaper general_stats medals',
    'reaper general_stats medals_bronze',
    'reaper general_stats medals_gold',
    'reaper general_stats medals_silver',
    'reaper general_stats melee_final_blow',
    'reaper general_stats melee_final_blow_most_in_game',
    'reaper general_stats melee_final_blows',
    'reaper general_stats melee_final_blows_most_in_game',
    'reaper general_stats multikill',
    'reaper general_stats multikill_best',
    'reaper general_stats multikills',
    'reaper general_stats objective_kill',
    'reaper general_stats objective_kill_most_in_game',
    'reaper general_stats objective_kills',
    'reaper general_stats objective_kills_most_in_game',
    'reaper general_stats objective_time',
    'reaper general_stats objective_time_most_in_game',
    'reaper general_stats overwatchguid0x0860000000000033',
    'reaper general_stats quick_melee_accuracy',
    'reaper general_stats shield_generator_destroyed',
    'reaper general_stats shield_generators_destroyed',
    'reaper general_stats solo_kill',
    'reaper general_stats solo_kill_most_in_game',
    'reaper general_stats solo_kills',
    'reaper general_stats solo_kills_most_in_game',
    'reaper general_stats teleporter_pad_destroyed',
    'reaper general_stats teleporter_pads_destroyed',
    'reaper general_stats time_played',
    'reaper general_stats time_spent_on_fire',
    'reaper general_stats time_spent_on_fire_most_in_game',
    'reaper general_stats turret_destroyed',
    'reaper general_stats turrets_destroyed',
    'reaper general_stats weapon_accuracy',
    'reaper general_stats weapon_accuracy_best_in_game',
    'reaper general_stats win_percentage',
    'reaper hero_stats death_blossom_kill',
    'reaper hero_stats death_blossom_kill_most_in_game',
    'reaper hero_stats death_blossom_kills',
    'reaper hero_stats death_blossom_kills_most_in_game',
    'reaper hero_stats self_healing',
    'reaper hero_stats self_healing_most_in_game',
    'reaper hero_stats sentry_turret_kills',
    'reaper hero_stats sentry_turret_kills_most_in_game',
    'reaper hero_stats teleporter_uptime',
    'reaper hero_stats turret_kills',
    'reaper rolling_average_stats all_damage_done',
    'reaper rolling_average_stats barrier_damage_done',
    'reaper rolling_average_stats critical_hits',
    'reaper rolling_average_stats death_blossom_kills',
    'reaper rolling_average_stats deaths',
    'reaper rolling_average_stats eliminations',
    'reaper rolling_average_stats final_blows',
    'reaper rolling_average_stats hero_damage_done',
    'reaper rolling_average_stats melee_final_blows',
    'reaper rolling_average_stats objective_kills',
    'reaper rolling_average_stats objective_time',
    'reaper rolling_average_stats self_healing',
    'reaper rolling_average_stats solo_kills',
    'reaper rolling_average_stats time_spent_on_fire',
    'reinhardt average_stats average_energy',
    'reinhardt general_stats all_damage_done',
    'reinhardt general_stats all_damage_done_most_in_game',
    'reinhardt general_stats all_damage_done_most_in_life',
    'reinhardt general_stats barrier_damage_done',
    'reinhardt general_stats barrier_damage_done_most_in_game',
    'reinhardt general_stats card',
    'reinhardt general_stats cards',
    'reinhardt general_stats death',
    'reinhardt general_stats deaths',
    'reinhardt general_stats elimination',
    'reinhardt general_stats elimination_most_in_game',
    'reinhardt general_stats elimination_most_in_life',
    'reinhardt general_stats elimination_per_life',
    'reinhardt general_stats eliminations',
    'reinhardt general_stats eliminations_most_in_game',
    'reinhardt general_stats eliminations_most_in_life',
    'reinhardt general_stats eliminations_per_life',
    'reinhardt general_stats environmental_kill',
    'reinhardt general_stats environmental_kills',
    'reinhardt general_stats final_blow',
    'reinhardt general_stats final_blow_most_in_game',
    'reinhardt general_stats final_blows',
    'reinhardt general_stats final_blows_most_in_game',
    'reinhardt general_stats games_lost',
    'reinhardt general_stats games_played',
    'reinhardt general_stats games_tied',
    'reinhardt general_stats games_won',
    'reinhardt general_stats healing_done',
    'reinhardt general_stats hero_damage_done',
    'reinhardt general_stats hero_damage_done_most_in_game',
    'reinhardt general_stats hero_damage_done_most_in_life',
    'reinhardt general_stats kill_streak_best',
    'reinhardt general_stats medals',
    'reinhardt general_stats medals_bronze',
    'reinhardt general_stats medals_gold',
    'reinhardt general_stats medals_silver',
    'reinhardt general_stats multikill',
    'reinhardt general_stats multikill_best',
    'reinhardt general_stats multikills',
    'reinhardt general_stats objective_kill',
    'reinhardt general_stats objective_kill_most_in_game',
    'reinhardt general_stats objective_kills',
    'reinhardt general_stats objective_kills_most_in_game',
    'reinhardt general_stats objective_time',
    'reinhardt general_stats objective_time_most_in_game',
    'reinhardt general_stats offensive_assist',
    'reinhardt general_stats offensive_assist_most_in_game',
    'reinhardt general_stats offensive_assists',
    'reinhardt general_stats offensive_assists_most_in_game',
    'reinhardt general_stats shield_generator_destroyed',
    'reinhardt general_stats shield_generators_destroyed',
    'reinhardt general_stats solo_kill',
    'reinhardt general_stats solo_kill_most_in_game',
    'reinhardt general_stats solo_kills',
    'reinhardt general_stats solo_kills_most_in_game',
    'reinhardt general_stats teleporter_pad_destroyed',
    'reinhardt general_stats teleporter_pads_destroyed',
    'reinhardt general_stats time_played',
    'reinhardt general_stats time_spent_on_fire',
    'reinhardt general_stats time_spent_on_fire_most_in_game',
    'reinhardt general_stats turret_destroyed',
    'reinhardt general_stats turrets_destroyed',
    'reinhardt general_stats win_percentage',
    'reinhardt hero_stats charge_kill',
    'reinhardt hero_stats charge_kill_most_in_game',
    'reinhardt hero_stats charge_kills',
    'reinhardt hero_stats charge_kills_most_in_game',
    'reinhardt hero_stats damage_blocked',
    'reinhardt hero_stats damage_blocked_most_in_game',
    'reinhardt hero_stats dragonstrike_kills',
    'reinhardt hero_stats earthshatter_kill',
    'reinhardt hero_stats earthshatter_kill_most_in_game',
    'reinhardt hero_stats earthshatter_kills',
    'reinhardt hero_stats earthshatter_kills_most_in_game',
    'reinhardt hero_stats fire_strike_kill',
    'reinhardt hero_stats fire_strike_kill_most_in_game',
    'reinhardt hero_stats fire_strike_kills',
    'reinhardt hero_stats fire_strike_kills_most_in_game',
    'reinhardt hero_stats rocket_hammer_melee_accuracy',
    'reinhardt hero_stats self_healing',
    'reinhardt rolling_average_stats all_damage_done',
    'reinhardt rolling_average_stats barrier_damage_done',
    'reinhardt rolling_average_stats charge_kills',
    'reinhardt rolling_average_stats damage_blocked',
    'reinhardt rolling_average_stats deaths',
    'reinhardt rolling_average_stats earthshatter_kills',
    'reinhardt rolling_average_stats eliminations',
    'reinhardt rolling_average_stats final_blows',
    'reinhardt rolling_average_stats fire_strike_kills',
    'reinhardt rolling_average_stats healing_done',
    'reinhardt rolling_average_stats hero_damage_done',
    'reinhardt rolling_average_stats objective_kills',
    'reinhardt rolling_average_stats objective_time',
    'reinhardt rolling_average_stats offensive_assists',
    'reinhardt rolling_average_stats self_healing',
    'reinhardt rolling_average_stats solo_kills',
    'reinhardt rolling_average_stats time_spent_on_fire',
    'roadhog average_stats average_energy',
    'roadhog general_stats all_damage_done',
    'roadhog general_stats all_damage_done_most_in_game',
    'roadhog general_stats all_damage_done_most_in_life',
    'roadhog general_stats barrier_damage_done',
    'roadhog general_stats barrier_damage_done_most_in_game',
    'roadhog general_stats card',
    'roadhog general_stats cards',
    'roadhog general_stats critical_hit',
    'roadhog general_stats critical_hit_accuracy',
    'roadhog general_stats critical_hit_most_in_game',
    'roadhog general_stats critical_hit_most_in_life',
    'roadhog general_stats critical_hits',
    'roadhog general_stats critical_hits_most_in_game',
    'roadhog general_stats critical_hits_most_in_life',
    'roadhog general_stats death',
    'roadhog general_stats deaths',
    'roadhog general_stats elimination',
    'roadhog general_stats elimination_most_in_game',
    'roadhog general_stats elimination_most_in_life',
    'roadhog general_stats elimination_per_life',
    'roadhog general_stats eliminations',
    'roadhog general_stats eliminations_most_in_game',
    'roadhog general_stats eliminations_most_in_life',
    'roadhog general_stats eliminations_per_life',
    'roadhog general_stats environmental_kill',
    'roadhog general_stats environmental_kills',
    'roadhog general_stats final_blow',
    'roadhog general_stats final_blow_most_in_game',
    'roadhog general_stats final_blows',
    'roadhog general_stats final_blows_most_in_game',
    'roadhog general_stats game_tied',
    'roadhog general_stats games_lost',
    'roadhog general_stats games_played',
    'roadhog general_stats games_tied',
    'roadhog general_stats games_won',
    'roadhog general_stats healing_done',
    'roadhog general_stats hero_damage_done',
    'roadhog general_stats hero_damage_done_most_in_game',
    'roadhog general_stats hero_damage_done_most_in_life',
    'roadhog general_stats kill_streak_best',
    'roadhog general_stats medals',
    'roadhog general_stats medals_bronze',
    'roadhog general_stats medals_gold',
    'roadhog general_stats medals_silver',
    'roadhog general_stats melee_final_blow',
    'roadhog general_stats melee_final_blow_most_in_game',
    'roadhog general_stats melee_final_blows',
    'roadhog general_stats melee_final_blows_most_in_game',
    'roadhog general_stats multikill',
    'roadhog general_stats multikill_best',
    'roadhog general_stats multikills',
    'roadhog general_stats objective_kill',
    'roadhog general_stats objective_kill_most_in_game',
    'roadhog general_stats objective_kills',
    'roadhog general_stats objective_kills_most_in_game',
    'roadhog general_stats objective_time',
    'roadhog general_stats objective_time_most_in_game',
    'roadhog general_stats offensive_assist',
    'roadhog general_stats offensive_assist_most_in_game',
    'roadhog general_stats offensive_assists',
    'roadhog general_stats offensive_assists_most_in_game',
    'roadhog general_stats overwatchguid0x0860000000000033',
    'roadhog general_stats quick_melee_accuracy',
    'roadhog general_stats shield_generator_destroyed',
    'roadhog general_stats shield_generators_destroyed',
    'roadhog general_stats solo_kill',
    'roadhog general_stats solo_kill_most_in_game',
    'roadhog general_stats solo_kills',
    'roadhog general_stats solo_kills_most_in_game',
    'roadhog general_stats teleporter_pad_destroyed',
    'roadhog general_stats teleporter_pads_destroyed',
    'roadhog general_stats time_played',
    'roadhog general_stats time_spent_on_fire',
    'roadhog general_stats time_spent_on_fire_most_in_game',
    'roadhog general_stats turret_destroyed',
    'roadhog general_stats turrets_destroyed',
    'roadhog general_stats weapon_accuracy',
    'roadhog general_stats weapon_accuracy_best_in_game',
    'roadhog general_stats win_percentage',
    'roadhog hero_stats enemies_hooked',
    'roadhog hero_stats enemies_hooked_most_in_game',
    'roadhog hero_stats enemy_hooked',
    'roadhog hero_stats enemy_hooked_most_in_game',
    'roadhog hero_stats hook_accuracy',
    'roadhog hero_stats hook_accuracy_best_in_game',
    'roadhog hero_stats hook_attempted',
    'roadhog hero_stats hooks_attempted',
    'roadhog hero_stats self_healing',
    'roadhog hero_stats self_healing_most_in_game',
    'roadhog hero_stats whole_hog_kill',
    'roadhog hero_stats whole_hog_kill_most_in_game',
    'roadhog hero_stats whole_hog_kills',
    'roadhog hero_stats whole_hog_kills_most_in_game',
    'roadhog rolling_average_stats all_damage_done',
    'roadhog rolling_average_stats barrier_damage_done',
    'roadhog rolling_average_stats critical_hits',
    'roadhog rolling_average_stats deaths',
    'roadhog rolling_average_stats eliminations',
    'roadhog rolling_average_stats enemies_hooked',
    'roadhog rolling_average_stats final_blows',
    'roadhog rolling_average_stats healing_done',
    'roadhog rolling_average_stats hero_damage_done',
    'roadhog rolling_average_stats melee_final_blows',
    'roadhog rolling_average_stats objective_kills',
    'roadhog rolling_average_stats objective_time',
    'roadhog rolling_average_stats offensive_assists',
    'roadhog rolling_average_stats self_healing',
    'roadhog rolling_average_stats solo_kills',
    'roadhog rolling_average_stats time_spent_on_fire',
    'roadhog rolling_average_stats whole_hog_kills',
    'soldier76 average_stats average_energy',
    'soldier76 general_stats all_damage_done',
    'soldier76 general_stats all_damage_done_most_in_game',
    'soldier76 general_stats all_damage_done_most_in_life',
    'soldier76 general_stats barrier_damage_done',
    'soldier76 general_stats barrier_damage_done_most_in_game',
    'soldier76 general_stats card',
    'soldier76 general_stats cards',
    'soldier76 general_stats critical_hit',
    'soldier76 general_stats critical_hit_accuracy',
    'soldier76 general_stats critical_hit_most_in_game',
    'soldier76 general_stats critical_hit_most_in_life',
    'soldier76 general_stats critical_hits',
    'soldier76 general_stats critical_hits_most_in_game',
    'soldier76 general_stats critical_hits_most_in_life',
    'soldier76 general_stats death',
    'soldier76 general_stats deaths',
    'soldier76 general_stats defensive_assist',
    'soldier76 general_stats defensive_assist_most_in_game',
    'soldier76 general_stats defensive_assists',
    'soldier76 general_stats defensive_assists_most_in_game',
    'soldier76 general_stats elimination',
    'soldier76 general_stats elimination_most_in_game',
    'soldier76 general_stats elimination_most_in_life',
    'soldier76 general_stats elimination_per_life',
    'soldier76 general_stats eliminations',
    'soldier76 general_stats eliminations_most_in_game',
    'soldier76 general_stats eliminations_most_in_life',
    'soldier76 general_stats eliminations_per_life',
    'soldier76 general_stats environmental_kill',
    'soldier76 general_stats environmental_kills',
    'soldier76 general_stats final_blow',
    'soldier76 general_stats final_blow_most_in_game',
    'soldier76 general_stats final_blows',
    'soldier76 general_stats final_blows_most_in_game',
    'soldier76 general_stats games_lost',
    'soldier76 general_stats games_played',
    'soldier76 general_stats games_tied',
    'soldier76 general_stats games_won',
    'soldier76 general_stats healing_done',
    'soldier76 general_stats healing_done_most_in_game',
    'soldier76 general_stats hero_damage_done',
    'soldier76 general_stats hero_damage_done_most_in_game',
    'soldier76 general_stats hero_damage_done_most_in_life',
    'soldier76 general_stats kill_streak_best',
    'soldier76 general_stats medals',
    'soldier76 general_stats medals_bronze',
    'soldier76 general_stats medals_gold',
    'soldier76 general_stats medals_silver',
    'soldier76 general_stats melee_final_blow',
    'soldier76 general_stats melee_final_blow_most_in_game',
    'soldier76 general_stats melee_final_blows',
    'soldier76 general_stats melee_final_blows_most_in_game',
    'soldier76 general_stats multikill',
    'soldier76 general_stats multikill_best',
    'soldier76 general_stats multikills',
    'soldier76 general_stats objective_kill',
    'soldier76 general_stats objective_kill_most_in_game',
    'soldier76 general_stats objective_kills',
    'soldier76 general_stats objective_kills_most_in_game',
    'soldier76 general_stats objective_time',
    'soldier76 general_stats objective_time_most_in_game',
    'soldier76 general_stats overwatchguid0x0860000000000033',
    'soldier76 general_stats quick_melee_accuracy',
    'soldier76 general_stats shield_generator_destroyed',
    'soldier76 general_stats shield_generators_destroyed',
    'soldier76 general_stats solo_kill',
    'soldier76 general_stats solo_kill_most_in_game',
    'soldier76 general_stats solo_kills',
    'soldier76 general_stats solo_kills_most_in_game',
    'soldier76 general_stats teleporter_pad_destroyed',
    'soldier76 general_stats teleporter_pads_destroyed',
    'soldier76 general_stats time_played',
    'soldier76 general_stats time_spent_on_fire',
    'soldier76 general_stats time_spent_on_fire_most_in_game',
    'soldier76 general_stats turret_destroyed',
    'soldier76 general_stats turrets_destroyed',
    'soldier76 general_stats weapon_accuracy',
    'soldier76 general_stats weapon_accuracy_best_in_game',
    'soldier76 general_stats win_percentage',
    'soldier76 hero_stats barrage_kills',
    'soldier76 hero_stats barrage_kills_most_in_game',
    'soldier76 hero_stats biotic_field_deployed',
    'soldier76 hero_stats biotic_field_healing_done',
    'soldier76 hero_stats biotic_fields_deployed',
    'soldier76 hero_stats helix_rocket_kills',
    'soldier76 hero_stats helix_rocket_kills_most_in_game',
    'soldier76 hero_stats helix_rockets_kills',
    'soldier76 hero_stats helix_rockets_kills_most_in_game',
    'soldier76 hero_stats self_healing',
    'soldier76 hero_stats self_healing_most_in_game',
    'soldier76 hero_stats tactical_visor_kill',
    'soldier76 hero_stats tactical_visor_kill_most_in_game',
    'soldier76 hero_stats tactical_visor_kills',
    'soldier76 hero_stats tactical_visor_kills_most_in_game',
    'soldier76 hero_stats turret_kills',
    'soldier76 rolling_average_stats all_damage_done',
    'soldier76 rolling_average_stats barrage_kills',
    'soldier76 rolling_average_stats barrier_damage_done',
    'soldier76 rolling_average_stats critical_hits',
    'soldier76 rolling_average_stats deaths',
    'soldier76 rolling_average_stats defensive_assists',
    'soldier76 rolling_average_stats eliminations',
    'soldier76 rolling_average_stats final_blows',
    'soldier76 rolling_average_stats healing_done',
    'soldier76 rolling_average_stats helix_rockets_kills',
    'soldier76 rolling_average_stats hero_damage_done',
    'soldier76 rolling_average_stats melee_final_blows',
    'soldier76 rolling_average_stats objective_kills',
    'soldier76 rolling_average_stats objective_time',
    'soldier76 rolling_average_stats self_healing',
    'soldier76 rolling_average_stats solo_kills',
    'soldier76 rolling_average_stats tactical_visor_kills',
    'soldier76 rolling_average_stats time_spent_on_fire',
    'sombra general_stats all_damage_done',
    'sombra general_stats all_damage_done_most_in_game',
    'sombra general_stats all_damage_done_most_in_life',
    'sombra general_stats barrier_damage_done',
    'sombra general_stats barrier_damage_done_most_in_game',
    'sombra general_stats card',
    'sombra general_stats cards',
    'sombra general_stats death',
    'sombra general_stats deaths',
    'sombra general_stats elimination',
    'sombra general_stats elimination_most_in_game',
    'sombra general_stats elimination_most_in_life',
    'sombra general_stats elimination_per_life',
    'sombra general_stats eliminations',
    'sombra general_stats eliminations_most_in_game',
    'sombra general_stats eliminations_most_in_life',
    'sombra general_stats eliminations_per_life',
    'sombra general_stats environmental_kill',
    'sombra general_stats final_blow',
    'sombra general_stats final_blow_most_in_game',
    'sombra general_stats final_blows',
    'sombra general_stats final_blows_most_in_game',
    'sombra general_stats games_lost',
    'sombra general_stats games_played',
    'sombra general_stats games_tied',
    'sombra general_stats games_won',
    'sombra general_stats hero_damage_done',
    'sombra general_stats hero_damage_done_most_in_game',
    'sombra general_stats hero_damage_done_most_in_life',
    'sombra general_stats kill_streak_best',
    'sombra general_stats medals',
    'sombra general_stats medals_bronze',
    'sombra general_stats medals_gold',
    'sombra general_stats medals_silver',
    'sombra general_stats melee_final_blow',
    'sombra general_stats melee_final_blow_most_in_game',
    'sombra general_stats melee_final_blows',
    'sombra general_stats melee_final_blows_most_in_game',
    'sombra general_stats multikill',
    'sombra general_stats multikill_best',
    'sombra general_stats multikills',
    'sombra general_stats objective_kill',
    'sombra general_stats objective_kill_most_in_game',
    'sombra general_stats objective_kills',
    'sombra general_stats objective_kills_most_in_game',
    'sombra general_stats objective_time',
    'sombra general_stats objective_time_most_in_game',
    'sombra general_stats offensive_assist',
    'sombra general_stats offensive_assist_most_in_game',
    'sombra general_stats offensive_assists',
    'sombra general_stats offensive_assists_most_in_game',
    'sombra general_stats overwatchguid0x0860000000000033',
    'sombra general_stats quick_melee_accuracy',
    'sombra general_stats shield_generator_destroyed',
    'sombra general_stats shield_generators_destroyed',
    'sombra general_stats solo_kill',
    'sombra general_stats solo_kill_most_in_game',
    'sombra general_stats solo_kills',
    'sombra general_stats solo_kills_most_in_game',
    'sombra general_stats teleporter_pad_destroyed',
    'sombra general_stats teleporter_pads_destroyed',
    'sombra general_stats time_played',
    'sombra general_stats time_spent_on_fire',
    'sombra general_stats time_spent_on_fire_most_in_game',
    'sombra general_stats turret_destroyed',
    'sombra general_stats turrets_destroyed',
    'sombra general_stats weapon_accuracy',
    'sombra general_stats weapon_accuracy_best_in_game',
    'sombra general_stats win_percentage',
    'sombra hero_stats enemies_empd',
    'sombra hero_stats enemies_empd_most_in_game',
    'sombra hero_stats enemies_hacked',
    'sombra hero_stats enemies_hacked_most_in_game',
    'sombra hero_stats enemy_empd',
    'sombra hero_stats enemy_empd_most_in_game',
    'sombra hero_stats enemy_hacked',
    'sombra hero_stats enemy_hacked_most_in_game',
    'sombra rolling_average_stats all_damage_done',
    'sombra rolling_average_stats barrier_damage_done',
    'sombra rolling_average_stats deaths',
    'sombra rolling_average_stats eliminations',
    'sombra rolling_average_stats enemies_empd',
    'sombra rolling_average_stats enemies_hacked',
    'sombra rolling_average_stats final_blows',
    'sombra rolling_average_stats hero_damage_done',
    'sombra rolling_average_stats melee_final_blows',
    'sombra rolling_average_stats objective_kills',
    'sombra rolling_average_stats objective_time',
    'sombra rolling_average_stats offensive_assists',
    'sombra rolling_average_stats solo_kills',
    'sombra rolling_average_stats time_spent_on_fire',
    'symmetra average_stats average_energy',
    'symmetra average_stats teleporter_uptime_average',
    'symmetra general_stats all_damage_done',
    'symmetra general_stats all_damage_done_most_in_game',
    'symmetra general_stats all_damage_done_most_in_life',
    'symmetra general_stats barrier_damage_done',
    'symmetra general_stats barrier_damage_done_most_in_game',
    'symmetra general_stats card',
    'symmetra general_stats cards',
    'symmetra general_stats death',
    'symmetra general_stats deaths',
    'symmetra general_stats elimination',
    'symmetra general_stats elimination_most_in_game',
    'symmetra general_stats elimination_most_in_life',
    'symmetra general_stats elimination_per_life',
    'symmetra general_stats eliminations',
    'symmetra general_stats eliminations_most_in_game',
    'symmetra general_stats eliminations_most_in_life',
    'symmetra general_stats eliminations_per_life',
    'symmetra general_stats final_blow',
    'symmetra general_stats final_blow_most_in_game',
    'symmetra general_stats final_blows',
    'symmetra general_stats final_blows_most_in_game',
    'symmetra general_stats game_lost',
    'symmetra general_stats game_played',
    'symmetra general_stats games_lost',
    'symmetra general_stats games_played',
    'symmetra general_stats games_tied',
    'symmetra general_stats games_won',
    'symmetra general_stats healing_done',
    'symmetra general_stats hero_damage_done',
    'symmetra general_stats hero_damage_done_most_in_game',
    'symmetra general_stats hero_damage_done_most_in_life',
    'symmetra general_stats kill_streak_best',
    'symmetra general_stats medals',
    'symmetra general_stats medals_bronze',
    'symmetra general_stats medals_gold',
    'symmetra general_stats medals_silver',
    'symmetra general_stats melee_final_blow',
    'symmetra general_stats melee_final_blow_most_in_game',
    'symmetra general_stats melee_final_blows',
    'symmetra general_stats melee_final_blows_most_in_game',
    'symmetra general_stats multikill',
    'symmetra general_stats multikill_best',
    'symmetra general_stats multikills',
    'symmetra general_stats objective_kill',
    'symmetra general_stats objective_kill_most_in_game',
    'symmetra general_stats objective_kills',
    'symmetra general_stats objective_kills_most_in_game',
    'symmetra general_stats objective_time',
    'symmetra general_stats objective_time_most_in_game',
    'symmetra general_stats quick_melee_accuracy',
    'symmetra general_stats shield_generator_destroyed',
    'symmetra general_stats shield_generators_destroyed',
    'symmetra general_stats solo_kill',
    'symmetra general_stats solo_kill_most_in_game',
    'symmetra general_stats solo_kills',
    'symmetra general_stats solo_kills_most_in_game',
    'symmetra general_stats teleporter_pad_destroyed',
    'symmetra general_stats teleporter_pads_destroyed',
    'symmetra general_stats time_played',
    'symmetra general_stats time_spent_on_fire',
    'symmetra general_stats time_spent_on_fire_most_in_game',
    'symmetra general_stats turret_destroyed',
    'symmetra general_stats turrets_destroyed',
    'symmetra general_stats win_percentage',
    'symmetra hero_stats damage_blocked',
    'symmetra hero_stats damage_blocked_most_in_game',
    'symmetra hero_stats player_teleported',
    'symmetra hero_stats player_teleported_most_in_game',
    'symmetra hero_stats players_teleported',
    'symmetra hero_stats players_teleported_most_in_game',
    'symmetra hero_stats primary_fire_accuracy',
    'symmetra hero_stats self_healing',
    'symmetra hero_stats sentry_turret_kill',
    'symmetra hero_stats sentry_turret_kill_most_in_game',
    'symmetra hero_stats sentry_turret_kills',
    'symmetra hero_stats sentry_turret_kills_most_in_game',
    'symmetra hero_stats shield_generator_uptime',
    'symmetra hero_stats teleporter_uptime',
    'symmetra hero_stats teleporter_uptime_best_in_game',
    'symmetra rolling_average_stats all_damage_done',
    'symmetra rolling_average_stats barrier_damage_done',
    'symmetra rolling_average_stats damage_blocked',
    'symmetra rolling_average_stats deaths',
    'symmetra rolling_average_stats eliminations',
    'symmetra rolling_average_stats final_blows',
    'symmetra rolling_average_stats healing_done',
    'symmetra rolling_average_stats hero_damage_done',
    'symmetra rolling_average_stats melee_final_blows',
    'symmetra rolling_average_stats objective_kills',
    'symmetra rolling_average_stats objective_time',
    'symmetra rolling_average_stats players_teleported',
    'symmetra rolling_average_stats self_healing',
    'symmetra rolling_average_stats sentry_turret_kills',
    'symmetra rolling_average_stats solo_kills',
    'symmetra rolling_average_stats time_spent_on_fire',
    'torbjorn average_stats average_energy',
    'torbjorn general_stats all_damage_done',
    'torbjorn general_stats all_damage_done_most_in_game',
    'torbjorn general_stats all_damage_done_most_in_life',
    'torbjorn general_stats barrier_damage_done',
    'torbjorn general_stats barrier_damage_done_most_in_game',
    'torbjorn general_stats card',
    'torbjorn general_stats cards',
    'torbjorn general_stats critical_hit',
    'torbjorn general_stats critical_hit_accuracy',
    'torbjorn general_stats critical_hit_most_in_game',
    'torbjorn general_stats critical_hit_most_in_life',
    'torbjorn general_stats critical_hits',
    'torbjorn general_stats critical_hits_most_in_game',
    'torbjorn general_stats critical_hits_most_in_life',
    'torbjorn general_stats death',
    'torbjorn general_stats deaths',
    'torbjorn general_stats elimination',
    'torbjorn general_stats elimination_most_in_game',
    'torbjorn general_stats elimination_most_in_life',
    'torbjorn general_stats elimination_per_life',
    'torbjorn general_stats eliminations',
    'torbjorn general_stats eliminations_most_in_game',
    'torbjorn general_stats eliminations_most_in_life',
    'torbjorn general_stats eliminations_per_life',
    'torbjorn general_stats environmental_kill',
    'torbjorn general_stats final_blow',
    'torbjorn general_stats final_blow_most_in_game',
    'torbjorn general_stats final_blows',
    'torbjorn general_stats final_blows_most_in_game',
    'torbjorn general_stats games_lost',
    'torbjorn general_stats games_played',
    'torbjorn general_stats games_tied',
    'torbjorn general_stats games_won',
    'torbjorn general_stats healing_done',
    'torbjorn general_stats hero_damage_done',
    'torbjorn general_stats hero_damage_done_most_in_game',
    'torbjorn general_stats hero_damage_done_most_in_life',
    'torbjorn general_stats kill_streak_best',
    'torbjorn general_stats medals',
    'torbjorn general_stats medals_bronze',
    'torbjorn general_stats medals_gold',
    'torbjorn general_stats medals_silver',
    'torbjorn general_stats melee_final_blow',
    'torbjorn general_stats melee_final_blow_most_in_game',
    'torbjorn general_stats melee_final_blows',
    'torbjorn general_stats melee_final_blows_most_in_game',
    'torbjorn general_stats multikill',
    'torbjorn general_stats multikill_best',
    'torbjorn general_stats multikills',
    'torbjorn general_stats objective_kill',
    'torbjorn general_stats objective_kill_most_in_game',
    'torbjorn general_stats objective_kills',
    'torbjorn general_stats objective_kills_most_in_game',
    'torbjorn general_stats objective_time',
    'torbjorn general_stats objective_time_most_in_game',
    'torbjorn general_stats overwatchguid0x0860000000000033',
    'torbjorn general_stats quick_melee_accuracy',
    'torbjorn general_stats shield_generator_destroyed',
    'torbjorn general_stats solo_kill',
    'torbjorn general_stats solo_kill_most_in_game',
    'torbjorn general_stats solo_kills',
    'torbjorn general_stats solo_kills_most_in_game',
    'torbjorn general_stats teleporter_pad_destroyed',
    'torbjorn general_stats teleporter_pads_destroyed',
    'torbjorn general_stats time_played',
    'torbjorn general_stats time_spent_on_fire',
    'torbjorn general_stats time_spent_on_fire_most_in_game',
    'torbjorn general_stats turret_destroyed',
    'torbjorn general_stats turrets_destroyed',
    'torbjorn general_stats weapon_accuracy',
    'torbjorn general_stats weapon_accuracy_best_in_game',
    'torbjorn general_stats win_percentage',
    'torbjorn hero_stats armor_pack_created',
    'torbjorn hero_stats armor_pack_created_most_in_game',
    'torbjorn hero_stats armor_packs_created',
    'torbjorn hero_stats armor_packs_created_most_in_game',
    'torbjorn hero_stats biotic_field_healing_done',
    'torbjorn hero_stats molten_core_kill',
    'torbjorn hero_stats molten_core_kill_most_in_game',
    'torbjorn hero_stats molten_core_kills',
    'torbjorn hero_stats molten_core_kills_most_in_game',
    'torbjorn hero_stats self_healing',
    'torbjorn hero_stats torbjorn_kill',
    'torbjorn hero_stats torbjorn_kill_most_in_game',
    'torbjorn hero_stats torbjorn_kills',
    'torbjorn hero_stats torbjorn_kills_most_in_game',
    'torbjorn hero_stats turret_kill',
    'torbjorn hero_stats turret_kill_most_in_game',
    'torbjorn hero_stats turret_kills',
    'torbjorn hero_stats turret_kills_most_in_game',
    'torbjorn rolling_average_stats all_damage_done',
    'torbjorn rolling_average_stats armor_packs_created',
    'torbjorn rolling_average_stats barrier_damage_done',
    'torbjorn rolling_average_stats critical_hits',
    'torbjorn rolling_average_stats deaths',
    'torbjorn rolling_average_stats eliminations',
    'torbjorn rolling_average_stats final_blows',
    'torbjorn rolling_average_stats healing_done',
    'torbjorn rolling_average_stats hero_damage_done',
    'torbjorn rolling_average_stats melee_final_blows',
    'torbjorn rolling_average_stats molten_core_kills',
    'torbjorn rolling_average_stats objective_kills',
    'torbjorn rolling_average_stats objective_time',
    'torbjorn rolling_average_stats solo_kills',
    'torbjorn rolling_average_stats time_spent_on_fire',
    'torbjorn rolling_average_stats torbjorn_kills',
    'torbjorn rolling_average_stats turret_kills',
    'tracer average_stats average_energy',
    'tracer general_stats all_damage_done',
    'tracer general_stats all_damage_done_most_in_game',
    'tracer general_stats all_damage_done_most_in_life',
    'tracer general_stats barrier_damage_done',
    'tracer general_stats barrier_damage_done_most_in_game',
    'tracer general_stats card',
    'tracer general_stats cards',
    'tracer general_stats critical_hit',
    'tracer general_stats critical_hit_accuracy',
    'tracer general_stats critical_hit_most_in_game',
    'tracer general_stats critical_hit_most_in_life',
    'tracer general_stats critical_hits',
    'tracer general_stats critical_hits_most_in_game',
    'tracer general_stats critical_hits_most_in_life',
    'tracer general_stats death',
    'tracer general_stats deaths',
    'tracer general_stats elimination',
    'tracer general_stats elimination_most_in_game',
    'tracer general_stats elimination_most_in_life',
    'tracer general_stats elimination_per_life',
    'tracer general_stats eliminations',
    'tracer general_stats eliminations_most_in_game',
    'tracer general_stats eliminations_most_in_life',
    'tracer general_stats eliminations_per_life',
    'tracer general_stats environmental_kill',
    'tracer general_stats environmental_kills',
    'tracer general_stats final_blow',
    'tracer general_stats final_blow_most_in_game',
    'tracer general_stats final_blows',
    'tracer general_stats final_blows_most_in_game',
    'tracer general_stats games_lost',
    'tracer general_stats games_played',
    'tracer general_stats games_tied',
    'tracer general_stats games_won',
    'tracer general_stats hero_damage_done',
    'tracer general_stats hero_damage_done_most_in_game',
    'tracer general_stats hero_damage_done_most_in_life',
    'tracer general_stats kill_streak_best',
    'tracer general_stats medals',
    'tracer general_stats medals_bronze',
    'tracer general_stats medals_gold',
    'tracer general_stats medals_silver',
    'tracer general_stats melee_final_blow',
    'tracer general_stats melee_final_blow_most_in_game',
    'tracer general_stats melee_final_blows',
    'tracer general_stats melee_final_blows_most_in_game',
    'tracer general_stats multikill',
    'tracer general_stats multikill_best',
    'tracer general_stats multikills',
    'tracer general_stats objective_kill',
    'tracer general_stats objective_kill_most_in_game',
    'tracer general_stats objective_kills',
    'tracer general_stats objective_kills_most_in_game',
    'tracer general_stats objective_time',
    'tracer general_stats objective_time_most_in_game',
    'tracer general_stats overwatchguid0x0860000000000033',
    'tracer general_stats quick_melee_accuracy',
    'tracer general_stats shield_generator_destroyed',
    'tracer general_stats shield_generators_destroyed',
    'tracer general_stats solo_kill',
    'tracer general_stats solo_kill_most_in_game',
    'tracer general_stats solo_kills',
    'tracer general_stats solo_kills_most_in_game',
    'tracer general_stats teleporter_pad_destroyed',
    'tracer general_stats teleporter_pads_destroyed',
    'tracer general_stats time_played',
    'tracer general_stats time_spent_on_fire',
    'tracer general_stats time_spent_on_fire_most_in_game',
    'tracer general_stats turret_destroyed',
    'tracer general_stats turrets_destroyed',
    'tracer general_stats weapon_accuracy',
    'tracer general_stats weapon_accuracy_best_in_game',
    'tracer general_stats win_percentage',
    'tracer hero_stats health_recovered',
    'tracer hero_stats health_recovered_most_in_game',
    'tracer hero_stats pulse_bomb_attached',
    'tracer hero_stats pulse_bomb_attached_most_in_game',
    'tracer hero_stats pulse_bomb_kill',
    'tracer hero_stats pulse_bomb_kill_most_in_game',
    'tracer hero_stats pulse_bomb_kills',
    'tracer hero_stats pulse_bomb_kills_most_in_game',
    'tracer hero_stats pulse_bombs_attached',
    'tracer hero_stats pulse_bombs_attached_most_in_game',
    'tracer hero_stats self_healing',
    'tracer hero_stats self_healing_most_in_game',
    'tracer rolling_average_stats all_damage_done',
    'tracer rolling_average_stats barrier_damage_done',
    'tracer rolling_average_stats critical_hits',
    'tracer rolling_average_stats deaths',
    'tracer rolling_average_stats eliminations',
    'tracer rolling_average_stats final_blows',
    'tracer rolling_average_stats health_recovered',
    'tracer rolling_average_stats hero_damage_done',
    'tracer rolling_average_stats melee_final_blows',
    'tracer rolling_average_stats objective_kills',
    'tracer rolling_average_stats objective_time',
    'tracer rolling_average_stats pulse_bomb_kills',
    'tracer rolling_average_stats pulse_bombs_attached',
    'tracer rolling_average_stats self_healing',
    'tracer rolling_average_stats solo_kills',
    'tracer rolling_average_stats time_spent_on_fire',
    'widowmaker general_stats all_damage_done',
    'widowmaker general_stats all_damage_done_most_in_game',
    'widowmaker general_stats all_damage_done_most_in_life',
    'widowmaker general_stats barrier_damage_done',
    'widowmaker general_stats barrier_damage_done_most_in_game',
    'widowmaker general_stats card',
    'widowmaker general_stats cards',
    'widowmaker general_stats critical_hit',
    'widowmaker general_stats critical_hit_accuracy',
    'widowmaker general_stats critical_hit_most_in_game',
    'widowmaker general_stats critical_hit_most_in_life',
    'widowmaker general_stats critical_hits',
    'widowmaker general_stats critical_hits_most_in_game',
    'widowmaker general_stats critical_hits_most_in_life',
    'widowmaker general_stats death',
    'widowmaker general_stats deaths',
    'widowmaker general_stats elimination',
    'widowmaker general_stats elimination_most_in_game',
    'widowmaker general_stats elimination_most_in_life',
    'widowmaker general_stats elimination_per_life',
    'widowmaker general_stats eliminations',
    'widowmaker general_stats eliminations_most_in_game',
    'widowmaker general_stats eliminations_most_in_life',
    'widowmaker general_stats eliminations_per_life',
    'widowmaker general_stats environmental_kill',
    'widowmaker general_stats final_blow',
    'widowmaker general_stats final_blow_most_in_game',
    'widowmaker general_stats final_blows',
    'widowmaker general_stats final_blows_most_in_game',
    'widowmaker general_stats games_lost',
    'widowmaker general_stats games_played',
    'widowmaker general_stats games_tied',
    'widowmaker general_stats games_won',
    'widowmaker general_stats hero_damage_done',
    'widowmaker general_stats hero_damage_done_most_in_game',
    'widowmaker general_stats hero_damage_done_most_in_life',
    'widowmaker general_stats kill_streak_best',
    'widowmaker general_stats medals',
    'widowmaker general_stats medals_bronze',
    'widowmaker general_stats medals_gold',
    'widowmaker general_stats medals_silver',
    'widowmaker general_stats melee_final_blow',
    'widowmaker general_stats melee_final_blow_most_in_game',
    'widowmaker general_stats melee_final_blows',
    'widowmaker general_stats melee_final_blows_most_in_game',
    'widowmaker general_stats multikill',
    'widowmaker general_stats multikill_best',
    'widowmaker general_stats multikills',
    'widowmaker general_stats objective_kill',
    'widowmaker general_stats objective_kill_most_in_game',
    'widowmaker general_stats objective_kills',
    'widowmaker general_stats objective_kills_most_in_game',
    'widowmaker general_stats objective_time',
    'widowmaker general_stats objective_time_most_in_game',
    'widowmaker general_stats overwatchguid0x0860000000000033',
    'widowmaker general_stats quick_melee_accuracy',
    'widowmaker general_stats recon_assist',
    'widowmaker general_stats recon_assist_most_in_game',
    'widowmaker general_stats recon_assists',
    'widowmaker general_stats recon_assists_most_in_game',
    'widowmaker general_stats shield_generator_destroyed',
    'widowmaker general_stats shield_generators_destroyed',
    'widowmaker general_stats solo_kill',
    'widowmaker general_stats solo_kill_most_in_game',
    'widowmaker general_stats solo_kills',
    'widowmaker general_stats solo_kills_most_in_game',
    'widowmaker general_stats teleporter_pad_destroyed',
    'widowmaker general_stats teleporter_pads_destroyed',
    'widowmaker general_stats time_played',
    'widowmaker general_stats time_spent_on_fire',
    'widowmaker general_stats time_spent_on_fire_most_in_game',
    'widowmaker general_stats turret_destroyed',
    'widowmaker general_stats turrets_destroyed',
    'widowmaker general_stats weapon_accuracy',
    'widowmaker general_stats weapon_accuracy_best_in_game',
    'widowmaker general_stats win_percentage',
    'widowmaker hero_stats scoped_accuracy',
    'widowmaker hero_stats scoped_accuracy_best_in_game',
    'widowmaker hero_stats scoped_critical_hit',
    'widowmaker hero_stats scoped_critical_hit_most_in_game',
    'widowmaker hero_stats scoped_critical_hits',
    'widowmaker hero_stats scoped_critical_hits_most_in_game',
    'widowmaker hero_stats venom_mine_kill',
    'widowmaker hero_stats venom_mine_kill_most_in_game',
    'widowmaker hero_stats venom_mine_kills',
    'widowmaker hero_stats venom_mine_kills_most_in_game',
    'widowmaker rolling_average_stats all_damage_done',
    'widowmaker rolling_average_stats barrier_damage_done',
    'widowmaker rolling_average_stats critical_hits',
    'widowmaker rolling_average_stats deaths',
    'widowmaker rolling_average_stats eliminations',
    'widowmaker rolling_average_stats final_blows',
    'widowmaker rolling_average_stats hero_damage_done',
    'widowmaker rolling_average_stats melee_final_blows',
    'widowmaker rolling_average_stats objective_kills',
    'widowmaker rolling_average_stats objective_time',
    'widowmaker rolling_average_stats recon_assists',
    'widowmaker rolling_average_stats scoped_critical_hits',
    'widowmaker rolling_average_stats solo_kills',
    'widowmaker rolling_average_stats time_spent_on_fire',
    'widowmaker rolling_average_stats venom_mine_kills',
    'winston average_stats average_energy',
    'winston average_stats teleporter_uptime_average',
    'winston general_stats all_damage_done',
    'winston general_stats all_damage_done_most_in_game',
    'winston general_stats all_damage_done_most_in_life',
    'winston general_stats barrier_damage_done',
    'winston general_stats barrier_damage_done_most_in_game',
    'winston general_stats card',
    'winston general_stats cards',
    'winston general_stats death',
    'winston general_stats deaths',
    'winston general_stats elimination',
    'winston general_stats elimination_most_in_game',
    'winston general_stats elimination_most_in_life',
    'winston general_stats elimination_per_life',
    'winston general_stats eliminations',
    'winston general_stats eliminations_most_in_game',
    'winston general_stats eliminations_most_in_life',
    'winston general_stats eliminations_per_life',
    'winston general_stats environmental_kill',
    'winston general_stats environmental_kills',
    'winston general_stats final_blow',
    'winston general_stats final_blow_most_in_game',
    'winston general_stats final_blows',
    'winston general_stats final_blows_most_in_game',
    'winston general_stats games_lost',
    'winston general_stats games_played',
    'winston general_stats games_tied',
    'winston general_stats games_won',
    'winston general_stats healing_done',
    'winston general_stats hero_damage_done',
    'winston general_stats hero_damage_done_most_in_game',
    'winston general_stats hero_damage_done_most_in_life',
    'winston general_stats jump_kill',
    'winston general_stats jump_kills',
    'winston general_stats kill_streak_best',
    'winston general_stats medals',
    'winston general_stats medals_bronze',
    'winston general_stats medals_gold',
    'winston general_stats medals_silver',
    'winston general_stats melee_final_blow',
    'winston general_stats melee_final_blow_most_in_game',
    'winston general_stats melee_final_blows',
    'winston general_stats melee_final_blows_most_in_game',
    'winston general_stats melee_kill',
    'winston general_stats melee_kills',
    'winston general_stats multikill',
    'winston general_stats multikill_best',
    'winston general_stats multikills',
    'winston general_stats objective_kill',
    'winston general_stats objective_kill_most_in_game',
    'winston general_stats objective_kills',
    'winston general_stats objective_kills_most_in_game',
    'winston general_stats objective_time',
    'winston general_stats objective_time_most_in_game',
    'winston general_stats quick_melee_accuracy',
    'winston general_stats shield_generator_destroyed',
    'winston general_stats shield_generators_destroyed',
    'winston general_stats solo_kill',
    'winston general_stats solo_kill_most_in_game',
    'winston general_stats solo_kills',
    'winston general_stats solo_kills_most_in_game',
    'winston general_stats teleporter_pad_destroyed',
    'winston general_stats teleporter_pads_destroyed',
    'winston general_stats time_played',
    'winston general_stats time_spent_on_fire',
    'winston general_stats time_spent_on_fire_most_in_game',
    'winston general_stats turret_destroyed',
    'winston general_stats turrets_destroyed',
    'winston general_stats weapon_kill',
    'winston general_stats weapon_kills',
    'winston general_stats win_percentage',
    'winston hero_stats damage_blocked',
    'winston hero_stats damage_blocked_most_in_game',
    'winston hero_stats jump_pack_kill',
    'winston hero_stats jump_pack_kill_most_in_game',
    'winston hero_stats jump_pack_kills',
    'winston hero_stats jump_pack_kills_most_in_game',
    'winston hero_stats melee_kill',
    'winston hero_stats melee_kill_most_in_game',
    'winston hero_stats melee_kills',
    'winston hero_stats melee_kills_most_in_game',
    'winston hero_stats player_knocked_back',
    'winston hero_stats player_knocked_back_most_in_game',
    'winston hero_stats players_knocked_back',
    'winston hero_stats players_knocked_back_most_in_game',
    'winston hero_stats primal_rage_kill',
    'winston hero_stats primal_rage_kill_most_in_game',
    'winston hero_stats primal_rage_kills',
    'winston hero_stats primal_rage_kills_most_in_game',
    'winston hero_stats primal_rage_melee_accuracy',
    'winston hero_stats teleporter_uptime',
    'winston hero_stats tesla_cannon_accuracy',
    'winston rolling_average_stats all_damage_done',
    'winston rolling_average_stats barrier_damage_done',
    'winston rolling_average_stats damage_blocked',
    'winston rolling_average_stats deaths',
    'winston rolling_average_stats eliminations',
    'winston rolling_average_stats final_blows',
    'winston rolling_average_stats healing_done',
    'winston rolling_average_stats hero_damage_done',
    'winston rolling_average_stats jump_pack_kills',
    'winston rolling_average_stats melee_final_blows',
    'winston rolling_average_stats melee_kills',
    'winston rolling_average_stats objective_kills',
    'winston rolling_average_stats objective_time',
    'winston rolling_average_stats players_knocked_back',
    'winston rolling_average_stats primal_rage_kills',
    'winston rolling_average_stats solo_kills',
    'winston rolling_average_stats time_spent_on_fire',
    'zarya average_stats average_energy',
    'zarya average_stats average_energy_best_in_game',
    'zarya average_stats teleporter_uptime_average',
    'zarya general_stats all_damage_done',
    'zarya general_stats all_damage_done_most_in_game',
    'zarya general_stats all_damage_done_most_in_life',
    'zarya general_stats barrier_damage_done',
    'zarya general_stats barrier_damage_done_most_in_game',
    'zarya general_stats card',
    'zarya general_stats cards',
    'zarya general_stats death',
    'zarya general_stats deaths',
    'zarya general_stats defensive_assist',
    'zarya general_stats defensive_assist_most_in_game',
    'zarya general_stats defensive_assists',
    'zarya general_stats defensive_assists_most_in_game',
    'zarya general_stats elimination',
    'zarya general_stats elimination_most_in_game',
    'zarya general_stats elimination_most_in_life',
    'zarya general_stats elimination_per_life',
    'zarya general_stats eliminations',
    'zarya general_stats eliminations_most_in_game',
    'zarya general_stats eliminations_most_in_life',
    'zarya general_stats eliminations_per_life',
    'zarya general_stats environmental_kill',
    'zarya general_stats environmental_kills',
    'zarya general_stats final_blow',
    'zarya general_stats final_blow_most_in_game',
    'zarya general_stats final_blows',
    'zarya general_stats final_blows_most_in_game',
    'zarya general_stats games_lost',
    'zarya general_stats games_played',
    'zarya general_stats games_tied',
    'zarya general_stats games_won',
    'zarya general_stats healing_done',
    'zarya general_stats hero_damage_done',
    'zarya general_stats hero_damage_done_most_in_game',
    'zarya general_stats hero_damage_done_most_in_life',
    'zarya general_stats kill_streak_best',
    'zarya general_stats medals',
    'zarya general_stats medals_bronze',
    'zarya general_stats medals_gold',
    'zarya general_stats medals_silver',
    'zarya general_stats melee_final_blow',
    'zarya general_stats melee_final_blow_most_in_game',
    'zarya general_stats melee_final_blows',
    'zarya general_stats melee_final_blows_most_in_game',
    'zarya general_stats multikill',
    'zarya general_stats multikill_best',
    'zarya general_stats multikills',
    'zarya general_stats objective_kill',
    'zarya general_stats objective_kill_most_in_game',
    'zarya general_stats objective_kills',
    'zarya general_stats objective_kills_most_in_game',
    'zarya general_stats objective_time',
    'zarya general_stats objective_time_most_in_game',
    'zarya general_stats offensive_assist',
    'zarya general_stats offensive_assist_most_in_game',
    'zarya general_stats offensive_assists',
    'zarya general_stats offensive_assists_most_in_game',
    'zarya general_stats quick_melee_accuracy',
    'zarya general_stats shield_generator_destroyed',
    'zarya general_stats shield_generators_destroyed',
    'zarya general_stats solo_kill',
    'zarya general_stats solo_kill_most_in_game',
    'zarya general_stats solo_kills',
    'zarya general_stats solo_kills_most_in_game',
    'zarya general_stats teleporter_pad_destroyed',
    'zarya general_stats teleporter_pads_destroyed',
    'zarya general_stats time_played',
    'zarya general_stats time_spent_on_fire',
    'zarya general_stats time_spent_on_fire_most_in_game',
    'zarya general_stats turret_destroyed',
    'zarya general_stats turrets_destroyed',
    'zarya general_stats weapon_accuracy',
    'zarya general_stats weapon_accuracy_best_in_game',
    'zarya general_stats win_percentage',
    'zarya hero_stats damage_blocked',
    'zarya hero_stats damage_blocked_most_in_game',
    'zarya hero_stats graviton_surge_kill',
    'zarya hero_stats graviton_surge_kill_most_in_game',
    'zarya hero_stats graviton_surge_kills',
    'zarya hero_stats graviton_surge_kills_most_in_game',
    'zarya hero_stats high_energy_kill',
    'zarya hero_stats high_energy_kill_most_in_game',
    'zarya hero_stats high_energy_kills',
    'zarya hero_stats high_energy_kills_most_in_game',
    'zarya hero_stats primary_fire_accuracy',
    'zarya hero_stats projected_barrier_applied',
    'zarya hero_stats projected_barrier_applied_most_in_game',
    'zarya hero_stats projected_barriers_applied',
    'zarya hero_stats projected_barriers_applied_most_in_game',
    'zarya hero_stats self_healing',
    'zarya hero_stats self_healing_most_in_game',
    'zarya hero_stats sentry_turret_kills',
    'zarya hero_stats teleporter_uptime',
    'zarya hero_stats turret_kills',
    'zarya rolling_average_stats all_damage_done',
    'zarya rolling_average_stats barrier_damage_done',
    'zarya rolling_average_stats damage_blocked',
    'zarya rolling_average_stats deaths',
    'zarya rolling_average_stats defensive_assists',
    'zarya rolling_average_stats eliminations',
    'zarya rolling_average_stats final_blows',
    'zarya rolling_average_stats graviton_surge_kills',
    'zarya rolling_average_stats hero_damage_done',
    'zarya rolling_average_stats high_energy_kills',
    'zarya rolling_average_stats melee_final_blows',
    'zarya rolling_average_stats objective_kills',
    'zarya rolling_average_stats objective_time',
    'zarya rolling_average_stats offensive_assists',
    'zarya rolling_average_stats projected_barriers_applied',
    'zarya rolling_average_stats solo_kills',
    'zarya rolling_average_stats time_spent_on_fire',
    'zenyatta average_stats average_energy',
    'zenyatta general_stats all_damage_done',
    'zenyatta general_stats all_damage_done_most_in_game',
    'zenyatta general_stats all_damage_done_most_in_life',
    'zenyatta general_stats barrier_damage_done',
    'zenyatta general_stats barrier_damage_done_most_in_game',
    'zenyatta general_stats card',
    'zenyatta general_stats cards',
    'zenyatta general_stats critical_hit',
    'zenyatta general_stats critical_hit_accuracy',
    'zenyatta general_stats critical_hit_most_in_game',
    'zenyatta general_stats critical_hit_most_in_life',
    'zenyatta general_stats critical_hits',
    'zenyatta general_stats critical_hits_most_in_game',
    'zenyatta general_stats critical_hits_most_in_life',
    'zenyatta general_stats death',
    'zenyatta general_stats deaths',
    'zenyatta general_stats defensive_assist',
    'zenyatta general_stats defensive_assist_most_in_game',
    'zenyatta general_stats defensive_assists',
    'zenyatta general_stats defensive_assists_most_in_game',
    'zenyatta general_stats elimination',
    'zenyatta general_stats elimination_most_in_game',
    'zenyatta general_stats elimination_most_in_life',
    'zenyatta general_stats elimination_per_life',
    'zenyatta general_stats eliminations',
    'zenyatta general_stats eliminations_most_in_game',
    'zenyatta general_stats eliminations_most_in_life',
    'zenyatta general_stats eliminations_per_life',
    'zenyatta general_stats environmental_kill',
    'zenyatta general_stats final_blow',
    'zenyatta general_stats final_blow_most_in_game',
    'zenyatta general_stats final_blows',
    'zenyatta general_stats final_blows_most_in_game',
    'zenyatta general_stats games_lost',
    'zenyatta general_stats games_played',
    'zenyatta general_stats games_tied',
    'zenyatta general_stats games_won',
    'zenyatta general_stats healing_done',
    'zenyatta general_stats healing_done_most_in_game',
    'zenyatta general_stats hero_damage_done',
    'zenyatta general_stats hero_damage_done_most_in_game',
    'zenyatta general_stats hero_damage_done_most_in_life',
    'zenyatta general_stats kill_streak_best',
    'zenyatta general_stats medals',
    'zenyatta general_stats medals_bronze',
    'zenyatta general_stats medals_gold',
    'zenyatta general_stats medals_silver',
    'zenyatta general_stats melee_final_blow',
    'zenyatta general_stats melee_final_blow_most_in_game',
    'zenyatta general_stats melee_final_blows',
    'zenyatta general_stats melee_final_blows_most_in_game',
    'zenyatta general_stats multikill',
    'zenyatta general_stats multikill_best',
    'zenyatta general_stats multikills',
    'zenyatta general_stats objective_kill',
    'zenyatta general_stats objective_kill_most_in_game',
    'zenyatta general_stats objective_kills',
    'zenyatta general_stats objective_kills_most_in_game',
    'zenyatta general_stats objective_time',
    'zenyatta general_stats objective_time_most_in_game',
    'zenyatta general_stats offensive_assist',
    'zenyatta general_stats offensive_assist_most_in_game',
    'zenyatta general_stats offensive_assists',
    'zenyatta general_stats offensive_assists_most_in_game',
    'zenyatta general_stats overwatchguid0x0860000000000033',
    'zenyatta general_stats quick_melee_accuracy',
    'zenyatta general_stats shield_generator_destroyed',
    'zenyatta general_stats shield_generators_destroyed',
    'zenyatta general_stats solo_kill',
    'zenyatta general_stats solo_kill_most_in_game',
    'zenyatta general_stats solo_kills',
    'zenyatta general_stats solo_kills_most_in_game',
    'zenyatta general_stats teleporter_pad_destroyed',
    'zenyatta general_stats teleporter_pads_destroyed',
    'zenyatta general_stats time_played',
    'zenyatta general_stats time_spent_on_fire',
    'zenyatta general_stats time_spent_on_fire_most_in_game',
    'zenyatta general_stats turret_destroyed',
    'zenyatta general_stats turrets_destroyed',
    'zenyatta general_stats weapon_accuracy',
    'zenyatta general_stats weapon_accuracy_best_in_game',
    'zenyatta general_stats win_percentage',
    'zenyatta hero_stats self_healing',
    'zenyatta hero_stats self_healing_most_in_game',
    'zenyatta hero_stats transcendence_healing',
    'zenyatta hero_stats transcendence_healing_best',
    'zenyatta rolling_average_stats all_damage_done',
    'zenyatta rolling_average_stats barrier_damage_done',
    'zenyatta rolling_average_stats critical_hits',
    'zenyatta rolling_average_stats deaths',
    'zenyatta rolling_average_stats defensive_assists',
    'zenyatta rolling_average_stats eliminations',
    'zenyatta rolling_average_stats final_blows',
    'zenyatta rolling_average_stats healing_done',
    'zenyatta rolling_average_stats hero_damage_done',
    'zenyatta rolling_average_stats melee_final_blows',
    'zenyatta rolling_average_stats objective_kills',
    'zenyatta rolling_average_stats objective_time',
    'zenyatta rolling_average_stats offensive_assists',
    'zenyatta rolling_average_stats self_healing',
    'zenyatta rolling_average_stats solo_kills',
    'zenyatta rolling_average_stats time_spent_on_fire'
]
